# %%
#%pip install torch torchvision fastai datasets pytorch-pretrained-biggan nltk torcheval
#%pip install pytorch-msssim
#%pip install numpy==1.26.4
# %pip install prun

# %%
# get the python version
import sys
print(sys.version)
is_38 = sys.version_info >= (3, 8)
# Out:
# 3.8.18 (default, Sep 11 2023, 08:17:16)
# [Clang 14.0.6 ]

# %%
import torch
import numpy as np
import os

from torchvision import datasets
from torchvision import transforms
import torchvision.transforms as T

import matplotlib.pyplot as plt
import pandas as pd

from numpy import genfromtxt

from PIL import Image

import random

# import visiondataset
from torchvision.datasets import VisionDataset
import pandas as pd

# %%
import pickle
from typing import Any, Callable, Dict, List, Optional, Tuple, Union
import torch.nn.functional as F

class MyDataset(VisionDataset):
    def __init__(
        self,
        root: str = ".",
        transform: Optional[Callable] = None,
        target_transform: Optional[Callable] = None,
        download: bool = False,
        normalize: Tuple[float, float] = None,
    ) -> None:
        super().__init__(root, transform=transform, target_transform=target_transform)

        self.labels = [ 'tg', 'Ng', 'Pci', 'Ph', 'Ox', 'Ow', 'Hbt' ]
        self.ids, self.data, self.features = self._load_data(root, ij=normalize)

    def __getitem__(self, index: int) -> Tuple[Any, Any]:
        """
        Args:
            index (int): Index

        Returns:
            tuple: (image, target) where target is index of the target class.
        """
        return  self.data[index], torch.tensor(self.features.iloc[index])

    def __len__(self) -> int:
        return len(self.data)
    
    def _load_data(self, root: str, ij: Tuple[float, float]):
        ids = pd.read_csv(f'{root}/PD_ids_train.csv')
        data = pd.read_csv(f'{root}/PD_imgs_np_train.csv')
        features = pd.read_csv(f'{root}/PD_conditions_train.csv')

        # convert all to list
        # TODO something better than a list
        ids = ids.values.tolist()
        data = [ torch.tensor(d) for d in data.values.tolist() ]
        features = features.values.tolist()

        data = torch.stack(data)
        data = data[:, 1:]

        data = data.reshape(len(data), 140, 39).float()
        data = 2 * (data / 255) - 1

        #                                         [ 'tg', 'Ng', 'Pci', 'H', 'Wp', 'Ph', 'Ox', 'Ow', 'Hbt', 'Wm', 'Wr' ]
        features = pd.DataFrame(features, columns=[ 'tg', 'Ng', 'Pci', 'H', 'Wp', 'Ph', 'Ox', 'Ow', 'Hbt', 'Wm', 'Wr']).astype('float32')

        if ij is not None:
            # drop fields that are not used
            features = features.drop(columns=['H', 'Wp', 'Wm', 'Wr'])

            # NOTE: (-1, 1) => y = 2 * (x - min) / (max - min) - 1
            #       ( i, j) => y = (j-i) * (x - min) / (max - min) + i
            features = (ij[1] - ij[0]) * (features - features.min()) / (features.max() - features.min()) + ij[0]
            # NOTE: they are nan because the min and max are the same, std is 0 (and mean is normally NaN); so we can just set them to 0
            features = features.fillna(0)

        return ids, data, features

# %%
dataset = MyDataset(root='data')
# get the count, mean, std, min, max, and sum of each column
df_aggregated = dataset.features.agg(['count', 'mean', 'std', 'min', 'max', 'sum']).reset_index()
display(df_aggregated)
# Out:
#    index             tg            Ng           Pci      H     Wp  \
# 0  count     668.000000    668.000000    668.000000  668.0  668.0
# 1   mean     333.500000     68.757782     38.844311    0.0    0.0
# 2    std     192.979279     52.810501     61.393608    0.0    0.0
# 3    min       0.000000      0.000000      0.000000    0.0    0.0
# 4    max     667.000000    200.000000    200.000000    0.0    0.0
# 5    sum  222778.000000  45930.199219  25948.000000    0.0    0.0
#
#               Ph            Ox           Ow            Hbt           Wm  \
# 0     668.000000    668.000000   668.000000     668.000000   668.000000
# 1     327.544922     25.612276     5.974551    1456.746948    12.199998
# 2      61.626793      3.267343     2.021091      20.019705     0.000000
# 3     300.000000     21.000000     3.000000    1410.000000    12.200000
# 4     500.000000     30.000000     9.000000    1485.000000    12.200000
# 5  218800.000000  17109.000000  3991.000000  973106.937500  8149.598633
#
#              Wr
# 0  6.680000e+02
# 1  3.087504e+05
# 2  0.000000e+00
# 3  3.087504e+05
# 4  3.087504e+05
# 5  2.062453e+08

# %%
pixels = 16
dataset = MyDataset(root='data', normalize=(-1, 1))
datum = dataset[0]
print(f"""
data: {datum[0]}
features: {datum[1]}
""")

# convert data to image plot
# TODO first pixel is bad
img = np.array(datum[0])
plt.imshow(img)

# img = img.reshape(-1, 128, 128)
# img = Image.fromarray((img * 255).astype(np.uint8)[0])
# plt.imshow(img)
# img2 = np.array(datum[0])
# img2 = img2[:-16].reshape(140, 39)
# plt.imshow(img2)

# downscale to 74x74
# remove the padding
# img = img[:-4].reshape(-1, 140, 39*3)
# img = img.reshape(-1, pixels, pixels)
# # img = F.interpolate(torch.Tensor(img).unsqueeze(0), size=(140, 39), mode='nearest').squeeze(0).numpy()
# print(img.shape)
# img = Image.fromarray((img * 255).astype(np.uint8)[0])
# plt.imshow(img)

conditions = np.array(datum[1])
features = pd.DataFrame([conditions], columns=dataset.labels)
display(features)
# Out:
# data: tensor([[ 1.0000,  1.0000,  1.0000,  ...,  1.0000,  1.0000,  1.0000],
#         [ 0.9922,  0.3020,  0.0353,  ...,  1.0000,  1.0000,  1.0000],
#         [ 1.0000, -0.1608, -0.6314,  ...,  1.0000,  1.0000,  1.0000],
#         ...,
#         [ 1.0000,  0.4745,  0.2706,  ...,  1.0000,  1.0000,  1.0000],
#         [ 1.0000,  0.9059,  0.8667,  ...,  1.0000,  1.0000,  1.0000],
#         [ 1.0000,  1.0000,  1.0000,  ...,  1.0000,  1.0000,  1.0000]])
# features: tensor([-1.0000,  0.5000, -1.0000,  1.0000, -0.3333,  0.6667,  0.3280])
#     tg   Ng  Pci   Ph        Ox        Ow       Hbt
# 0 -1.0  0.5 -1.0  1.0 -0.333333  0.666667  0.328001

# %%
# get the count, mean, std, min, max, and sum of each column
df_aggregated = dataset.features.agg(['count', 'mean', 'std', 'min', 'max', 'sum']).reset_index()
display(df_aggregated)

# remove the tg column from the dataset
# dataset.features = dataset.features.drop(columns=['tg'])
# Out:
#    index            tg          Ng         Pci          Ph          Ox  \
# 0  count  6.680000e+02  668.000000  668.000000  668.000000  668.000000
# 1   mean -2.284250e-08   -0.312422   -0.611557   -0.724551    0.024950
# 2    std  5.786485e-01    0.528105    0.613936    0.616268    0.726076
# 3    min -1.000000e+00   -1.000000   -1.000000   -1.000000   -1.000000
# 4    max  1.000000e+00    1.000000    1.000000    1.000000    1.000000
# 5    sum -1.525879e-05 -208.697998 -408.519989 -484.000000   16.666679
#
#            Ow         Hbt
# 0  668.000000  668.000000
# 1   -0.008483    0.246588
# 2    0.673697    0.533859
# 3   -1.000000   -1.000000
# 4    1.000000    1.000000
# 5   -5.666660  164.720627

# %%
# get the memory usage so far
print(f"Memory usage: {dataset.features.memory_usage().sum()} bytes")
# Out:
# Memory usage: 18832 bytes

# %% [markdown]
# # CGAN

# %%
import torch
import numpy as np
import os

from torchvision import datasets
from torchvision import transforms
import torchvision.transforms as T

import matplotlib.pyplot as plt
import pandas as pd

from numpy import genfromtxt

from PIL import Image

import random

# import visiondataset
from torchvision.datasets import VisionDataset

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_score, recall_score, accuracy_score, f1_score

# %%
from torch.utils.data import TensorDataset, DataLoader

import torch.optim as optim 
import torch.nn as nn


import torch.nn.functional as F

from torch.autograd import Variable

from fastai.vision.all import *
from fastai.vision.gan import *

from fastai.callback.all import *

# %%
from datasets import load_dataset, Split
import torch.autograd as autograd
from torcheval.metrics import PeakSignalNoiseRatio

# %%
channels = 1 ## 1 for B&W, 3 for RGB, 4 for RGBA

learning_rate    = 2e-4 #0.003  ## Adam default   ## 0.001 2e-4#
batch_size       = 16
N_Epochs         = 1 #4_000  ##27000  
num_classes = 1
width = 39
height = 140
img_size = width*height*channels
certainty_repeater = 6# channels**2 - num_classes

print(f"{img_size}")

if torch.cuda.is_available():
    device = torch.device('cuda')
    # get number of cuda devices
    print(f"devices: {torch.cuda.device_count()}")
    print(f"device:  {torch.cuda.get_device_name()}")
    print(f"device0: {torch.cuda.get_device_properties(0)}")
    print(f"{torch.cuda.memory_summary()}")
elif torch.backends.mps is not None:
    device = torch.device('mps')
    print(f"{torch.mps.current_allocated_memory()}")
    os.environ['PYTORCH_ENABLE_MPS_FALLBACK'] = '1'
else:
    device = torch.device('cpu')
    # print a warning that cpu is being used
    print("Warning: Running on CPU. This will be slow.")
print(f"{device}")
# Out:
# 5460
# 1771533568
# mps

# %%
# convert the dataset into a train / test split
# TODO i dont think test is used
# need to keep the split for each new run, to continue the epochs and same data
# TODO keep this, nicer, or use seed as file label
train_dataset, test_dataset = torch.utils.data.random_split(dataset, [0.85, 0.15], generator=torch.Generator().manual_seed(42))

# define the dataloader
dl_train = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
dl_test = DataLoader(test_dataset, batch_size=batch_size, shuffle=True)

# %%
def plot_GAN_losses(losses: List[Tuple[float, float]]):
    losses_generator = [i[0] for i in losses]
    losses_critic = [i[1] for i in losses]

    n_epochs = [i for i in range(len(losses))]  

    plt.plot(n_epochs, losses_critic,      label = "critic") 
    plt.plot(n_epochs, losses_generator,  label = "generator")
    plt.legend() 
    plt.show()

# %%
def print_metrics_function(y_test, y_pred):
    print('Accuracy: %.2f' % accuracy_score(y_test, y_pred))
    confmat = confusion_matrix(y_true=y_test, y_pred=y_pred)
    print("Confusion Matrix:")
    print(confmat)
    print('Precision: %.3f' % precision_score(y_true=y_test, y_pred=y_pred, average='weighted'))
    print('Recall: %.3f' % recall_score(y_true=y_test, y_pred=y_pred, average='weighted'))
    f1_measure = f1_score(y_true=y_test, y_pred=y_pred, average='weighted')
    print('F1-mesure: %.3f' % f1_measure)
    return f1_measure, confmat

# %%
def plot_metric_per_epoch(the_scores_list):
    # metrics = {}
    # metrics = []
    print(the_scores_list[0])
    epochs = [ the_scores_list['epoch'] for metric in the_scores_list ]
    for metric in the_scores_list:
        test = [ the_scores_list[metric] for metric in the_scores_list ]

    # x_epochs = []
    # y_epochs = [] 
    # for i, val in enumerate(the_scores_list):
    #     x_epochs.append(i)
    #     y_epochs.append(val)
    
        plt.scatter(epochs, test ,s=50,c='lightgreen', marker='s', label='score')
        plt.xlabel('epoch')
        plt.ylabel('score')
        plt.title('Score per epoch')
        plt.legend()
        plt.grid()
        plt.show()

# %%
def get_metrics(epoch):
    # using train_dl each time anywhere will give different values each time
    test = [ x for x in test_dataset ]

    real = torch.stack([x[0] for x in test], dim=0).to(device).unsqueeze(1)

    labels = torch.stack([x[1] for x in test], dim=0).to(device)
    labels = labels.repeat(1, 3).to(device)

    rand = noise_batch(len(real)).to(device)
    noise = torch.cat( (rand, labels) , dim=1)
    fake = G_model.forward( noise )

    psnr = PeakSignalNoiseRatio(device=device)
    psnr.update(fake, real)

    real = real.detach().cpu()
    fake = fake.detach().cpu()
    labels = labels.detach().cpu()

    metric = {
        'sanity': labels[0], # should always be the same
        'epoch': epoch,
    }

    return metric, fake

# %%
def random_G_vector_input():
    rand_vec = torch.randn( 100 ).to(device)
    return rand_vec

# %%
def noise_batch(batch_size=None):
    if batch_size is None:
        return torch.randn(100).to(device)
    else:
        return torch.randn(batch_size, 100).to(device)

# %%
def random_G_batch_vector_input():
    rand_vec = torch.randn( (batch_size, 100 ) ).to(device)
    return rand_vec

# %%
def random_batch_one_hot_rc(batch_size, size):
    rand_vec = torch.zeros( (batch_size, num_classes ) ).to(device)
    for i in range(batch_size):
        random_idx = random.randint(0,size-1)
        rand_vec[i, random_idx] = 1.0
    return rand_vec

# %%
import datetime
import tqdm

losses = []
metrics = []
fakes = []

def training_loop(N_Epochs, G_model, D_model, D_loss_fn, G_opt, D_opt,
                  checkpoint='checkpoint', save_interval: int = None, stop_after: datetime.timedelta = None, start_epoch: int = None):
    global losses
    global metrics
    global fakes
    
    if start_epoch is not None:
        G_model.load_state_dict(torch.load(f"{checkpoint}/G_{start_epoch}.pt"))
        D_model.load_state_dict(torch.load(f"{checkpoint}/D_{start_epoch}.pt"))
        losses = torch.load(f"{checkpoint}/l_{start_epoch}.pkl")
        metrics = torch.load(f"{checkpoint}/m_{start_epoch}.pkl")
        fakes = torch.load(f"{checkpoint}/f_{start_epoch}.pkl")
        
        print(f"loaded {checkpoint}/*_{start_epoch}")
    else:
        start_epoch = 0
    
    start_time = datetime.datetime.now()
    last_time = datetime.datetime.min
    pbar = tqdm.tqdm(range(start_epoch, N_Epochs+1))
    # pbar.update(start_epoch) # update with start makes it double. only one does nothing
    
    # TODO pbar jump to start
    for epoch in pbar:
        # shuffle dl_train every epoch
        # dataset = MyDataset(root='data', normalize=(-1, 1), transform=transforms.Compose([
        #     transforms.RandomHorizontalFlip(),
        #     transforms.RandomVerticalFlip()
        # ]))
        # train_dataset, test_dataset = torch.utils.data.random_split(dataset, [0.95, 0.05])
        dl_train = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
        
        for xb, yb in dl_train:              ## xb = [batch, 1, 28, 28]
            xb, yb = xb.to(device), yb.to(device)
            # print the memory usage of mps

            if xb.shape[0] != batch_size:
                # print(f"skipping batch of size {xb.shape[0]}")
                continue

            # xb = xb.reshape(batch_size, 128, width)
            # xb = F.pad(xb, (0, 128-width, 0, 0), value=-1) # TODO set to min
            yb = yb.repeat(1, 3)
            xb = torch.unsqueeze(xb, dim=1)
            # pad the image to 140x140
            # convert nb [batch, 384] to [batch, -1, 32, channels]

            yb_certainty = yb.repeat(channels, 140, 1, 1).permute(2, 0, 1, 3)#1, 0, 2) # [ batch, x (classes), y, channels ]
            real = torch.cat( (xb, yb_certainty) , dim=3)
            # print the real image
            # plt.imshow(real[0].squeeze(0).cpu().detach().numpy())

            # print the real image TODO this will print nothing because it is normalized to highest number
            # plt.imshow(real[0].squeeze(0).cpu().detach().numpy())

            for _ in range(5):
                noise = torch.cat( (random_G_batch_vector_input(), yb) , dim=1)
                fake = G_model( noise )#.detach()
                real_pred = D_model( real  ).reshape(-1)
                inputs = torch.cat( (fake, yb_certainty) , dim=3)
                fake_pred = D_model(  inputs  ).reshape(-1)

                fake_loss   = D_loss_fn(D_model, inputs, real, real_pred, fake_pred)
                # D_opt.zero_grad()
                D_model.zero_grad()
                fake_loss.backward(retain_graph=True)
                D_opt.step()
                
            output = D_model( inputs ).reshape(-1)
            gen_loss = -torch.mean(output)
            G_model.zero_grad()
            gen_loss.backward()
            G_opt.step()


        if epoch % 1 == 0:
            loss = (
                gen_loss.cpu().detach().numpy(),
                fake_loss.cpu().detach().numpy()
            )
            losses.append(loss)
            D_gen_loss_rnd = np.round(loss[0], 3)
            D_fake_loss_rnd = np.round(loss[1], 3)

            # not rounded anymore :(
            message = f"gen: {D_gen_loss_rnd}; crit: {D_fake_loss_rnd}"
            pbar.set_description(message)
            
        # draw an image of each class
        # place them all on the same figure
        # if epoch % 100 == 0:
        if datetime.datetime.now() > last_time + datetime.timedelta(minutes=10):
            last_time = datetime.datetime.now()
            f, axarr = plt.subplots(nrows=1, ncols=4, figsize=(12,4))
            
            for i in range(2):
                label = dataset[i][1].unsqueeze(0).repeat(1, 3).to(device)

                # create noise and make it 2d
                noise = random_G_vector_input().unsqueeze(0)
                inputs = torch.cat( (noise, label) , dim=1)
                output = G_model( inputs ).squeeze(0).cpu()
                
                img = output.detach().numpy()

                img = Image.fromarray((img * 255).astype(np.uint8)[0], mode='L')
                # display the image
                # (1, 16, 16) => (16, 16)
                
                axarr[i].imshow(img)

                # show the original image
                img = dataset[i][0].cpu().detach().numpy()
                axarr[i+2].imshow(Image.fromarray((img * 255).astype(np.uint8), mode='L'))

            # save the plot
            plt.savefig(f"{checkpoint}/epoch_{epoch}.png")
            plt.show()
            
            metric, fake = get_metrics(epoch)
            metrics.append(metric)
            fakes.append(fake)
        
        if save_interval is not None and epoch % save_interval == 0:
            torch.save(G_model.state_dict(), f"{checkpoint}/G_{epoch}.pt")
            torch.save(D_model.state_dict(), f"{checkpoint}/D_{epoch}.pt")
            
            torch.save(losses, f"{checkpoint}/l_{epoch}.pkl")
            torch.save(metrics, f"{checkpoint}/m_{epoch}.pkl")
            torch.save(fakes, f"{checkpoint}/f_{epoch}.pkl")
        
        if stop_after is not None and datetime.datetime.now() > start_time+stop_after:
            print(f"Stopping training because it has been {datetime.datetime.now() - start_time} since {start_time}")
            break

    torch.save(G_model.state_dict(), f"{checkpoint}/G_{epoch}.pt")
    torch.save(D_model.state_dict(), f"{checkpoint}/D_{epoch}.pt")
    torch.save(losses, f"{checkpoint}/l_{epoch}.pkl")
    torch.save(metrics, f"{checkpoint}/m_{epoch}.pkl")
    torch.save(fakes, f"{checkpoint}/f_{epoch}.pkl")

# %%
def grad_penatly(critic, real, fake):
    # Random weight term for interpolation between real and fake samples
    batch, c, h, w = real.shape
    epsilon = torch.rand((batch, 1, 1, 1)).repeat(1, c, h, w).to(device)
    interpolated_images = real * epsilon + fake * (1 - epsilon)

    # Calculate critic scores
    mixed_scores = critic(interpolated_images)
    gradient = torch.autograd.grad(
        inputs=interpolated_images,
        outputs=mixed_scores,
        grad_outputs=torch.ones_like(mixed_scores),
        create_graph=True,
        retain_graph=True,
    )[0]

    # Take the norm of the gradient
    gradient = gradient.view(gradient.shape[0], -1)
    grad_norm = gradient.norm(2, dim=1) # L2 norm (euclidean norm)
    gradient_penalty = torch.mean((grad_norm - 1) ** 2)
    return gradient_penalty

def wasserstein_loss(D_model, gen_img, real_data, real_pred, fake_pred):
    loss =  - (real_pred.mean() - fake_pred.mean()) + 10 * grad_penatly(D_model, real_data, gen_img)
    return loss

# %%
class ModifiedGenerator(nn.Module):
    def __init__(self, size, in_sz, channels, extra_layers):
        super().__init__()
        self.basic_gen = basic_generator(size, in_sz=in_sz, n_channels=channels, n_extra_layers=extra_layers)
        # Remove the final layer and add adaptive ones
        self.basic_gen.final_layer = nn.Identity()
        
        # Add custom final layers
        self.adaptive_conv = nn.ConvTranspose2d(1, 32, 4, 2, 1)
        self.final_conv = nn.Conv2d(32, 1, 3, 1, 1)
        # self.adaptive_pool = nn.AdaptiveAvgPool2d((39, 140)) # Adaptive pool MPS: input sizes must be divisible by output sizes.
        
    def forward(self, z):
        x = self.basic_gen(z)  # Gets you to ~128×128
        x = self.adaptive_conv(x)
        x = self.final_conv(x)
        # x = self.adaptive_pool(x)  # Force exact dimensions
        x = F.interpolate(x, size=(140, 39), mode='bilinear', align_corners=False)
        return x

# %%
G_model     =  ModifiedGenerator(128, in_sz=100+7*3, channels=channels, extra_layers=1)

#import resnet 50
from torchvision.models import resnet50

# TODO storing it wrong. maybe see how they compare. something odd in it
# TODO but not that other thing. makes no sense. wouldnt even matter. and it works without
# maybe watch xb stuff
D_model = resnet50(pretrained=True)

# make resnet input same channels
D_model.conv1 = torch.nn.Conv2d(channels, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
# # Replace maxpool with avgpool (used to work without this, might be MPS thing)
D_model.maxpool = nn.AvgPool2d(kernel_size=3, stride=2, padding=1)
# make resnet output 2 classes
D_model.fc = torch.nn.Linear(in_features=2048, out_features=2, bias=True)

D_loss_fn = wasserstein_loss

G_opt       = torch.optim.Adam( G_model.parameters(), lr=learning_rate, betas=(0.0, 0.9) )
D_opt       = torch.optim.Adam( D_model.parameters(), lr=learning_rate, betas=(0.0, 0.9) )

# move everything to device
G_model.to(device)
D_model.to(device)

# %prun training_loop(  N_Epochs, G_model, D_model, D_loss_fn, G_opt, D_opt, checkpoint='checkpoint', save_interval=100, stop_after=None, start_epoch=None   )
# Out:
# /Users/oniichan/anaconda3/envs/its530_py38/lib/python3.8/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /Users/oniichan/anaconda3/envs/its530_py38/lib/python3.8/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# gen: 11.12600040435791; crit: -14.803999900817871:   0%|          | 0/2 [00:59<?, ?it/s]/var/folders/8v/kyhpjx6d3y1b7dp0twz_83sw0000gn/T/ipykernel_20221/3231231962.py:113: RuntimeWarning: invalid value encountered in cast
#   img = Image.fromarray((img * 255).astype(np.uint8)[0], mode='L')
# /var/folders/8v/kyhpjx6d3y1b7dp0twz_83sw0000gn/T/ipykernel_20221/3231231962.py:121: RuntimeWarning: invalid value encountered in cast
#   axarr[i+2].imshow(Image.fromarray((img * 255).astype(np.uint8), mode='L'))
# gen: 39.86199951171875; crit: -60.744998931884766: 100%|██████████| 2/2 [02:07<00:00, 63.69s/it]
#          6502731 function calls (5823834 primitive calls) in 127.627 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#       770   89.774    0.117   89.774    0.117 {method 'run_backward' of 'torch._C._EngineBase' objects}
#     61478    8.561    0.000    8.561    0.000 {built-in method torch.batch_norm}
#       353    4.791    0.014    4.791    0.014 {built-in method torch._C._nn.upsample_bilinear2d}
#    119438    3.143    0.000    3.143    0.000 {method 'add_' of 'torch._C.TensorBase' objects}
#     59713    2.829    0.000    2.829    0.000 {built-in method torch.conv2d}
#       420    2.329    0.006   12.552    0.030 adam.py:336(_single_tensor_adam)
#     57960    2.254    0.000    2.254    0.000 {method 'addcmul_' of 'torch._C.TensorBase' objects}
#     57960    2.207    0.000    2.207    0.000 {method 'addcdiv_' of 'torch._C.TensorBase' objects}
#     57960    1.987    0.000    1.987    0.000 {method 'mul_' of 'torch._C.TensorBase' objects}
#     57960    1.622    0.000    1.622    0.000 {method 'sqrt' of 'torch._C.TensorBase' objects}
#     54880    1.418    0.000    1.418    0.000 {built-in method torch.relu_}
#       853    1.397    0.002    1.397    0.002 {method 'to' of 'torch._C.TensorBase' objects}
#     17920    0.798    0.000   15.163    0.001 resnet.py:143(forward)
#         1    0.392    0.392  127.625  127.625 3231231962.py:8(training_loop)
#        10    0.309    0.031    0.495    0.049 serialization.py:780(_save)
#     57960    0.305    0.000    0.305    0.000 {method 'lerp_' of 'torch._C.TensorBase' objects}
#    679101    0.224    0.000    0.224    0.000 module.py:1675(__getattr__)
#      2824    0.214    0.000    0.214    0.000 {built-in method torch.conv_transpose2d}
# 216255/1475    0.208    0.000   21.364    0.014 module.py:1513(_call_impl)
#     61478    0.177    0.000   10.470    0.000 batchnorm.py:141(forward)
#       722    0.166    0.000    0.166    0.000 {method 'copy_' of 'torch._C.StorageBase' objects}
# 216255/1475    0.090    0.000   21.366    0.014 module.py:1507(_wrapped_call_impl)
#       350    0.089    0.000    8.822    0.025 3019302173.py:1(grad_penatly)
#        10    0.086    0.009    0.086    0.009 {method 'encode' of 'ImagingEncoder' objects}
#     61478    0.085    0.000    8.730    0.000 functional.py:2451(batch_norm)
#       420    0.083    0.000    0.115    0.000 adam.py:80(_init_group)
#      2118    0.082    0.000    0.082    0.000 {built-in method torch.relu}
#       770    0.078    0.000    0.078    0.000 {built-in method torch.ones_like}
#       420    0.076    0.000    0.258    0.001 module.py:2438(zero_grad)
# 263270/55510    0.072    0.000    0.079    0.000 module.py:2333(named_modules)
#      1120    0.062    0.000    0.062    0.000 {built-in method torch._C._nn.linear}
#       773    0.060    0.000    0.060    0.000 {built-in method torch.cat}
#       493    0.057    0.000    0.057    0.000 {method 'repeat' of 'torch._C.TensorBase' objects}
#      1120    0.056    0.000    0.056    0.000 {built-in method torch._C._nn.adaptive_avg_pool2d}
#      1120    0.052    0.000    0.052    0.000 {built-in method torch._C._nn.avg_pool2d}
#       350    0.052    0.000    8.897    0.025 3019302173.py:23(wasserstein_loss)
#     59713    0.048    0.000    2.943    0.000 conv.py:459(forward)
#     58380    0.047    0.000    0.165    0.000 module.py:2157(_named_members)
#    216256    0.047    0.000    0.047    0.000 {built-in method torch._C._get_tracing_state}
#     61478    0.041    0.000    0.045    0.000 functional.py:2434(_verify_batch_size)
#     57960    0.041    0.000    0.070    0.000 optimizer.py:84(_get_value)
#     59713    0.036    0.000    2.865    0.000 conv.py:451(_conv_forward)
#     57960    0.031    0.000    0.045    0.000 optimizer.py:97(_dispatch_sqrt)
# 11431/4833    0.030    0.000   16.002    0.003 container.py:215(forward)
#       350    0.027    0.000    0.027    0.000 {built-in method torch.norm}
#    115920    0.027    0.000    0.027    0.000 {built-in method torch.is_complex}
#     56998    0.026    0.000    1.531    0.000 functional.py:1462(relu)
#       700    0.023    0.000    0.023    0.000 {method 'mean' of 'torch._C.TensorBase' objects}
#     57962    0.023    0.000    0.023    0.000 {method 'item' of 'torch._C.TensorBase' objects}
#     56998    0.022    0.000    1.553    0.000 activation.py:100(forward)
# 270085/269507    0.020    0.000    0.026    0.000 {built-in method builtins.isinstance}
#       420    0.018    0.000    0.018    0.000 {built-in method torch.mean}
#     61478    0.016    0.000    0.023    0.000 batchnorm.py:418(_check_input_dim)
#       494    0.016    0.000    0.016    0.000 {built-in method torch._ops.profiler._record_function_enter_new}
#       350    0.016    0.000    0.016    0.000 {method 'pow' of 'torch._C.TensorBase' objects}
#       350    0.016    0.000    0.016    0.000 {built-in method torch.rsub}
#    174064    0.015    0.000    0.022    0.000 _tensor.py:1034(__hash__)
#     64024    0.015    0.000    0.015    0.000 {method 'size' of 'torch._C.TensorBase' objects}
#      1120    0.014    0.000   15.832    0.014 resnet.py:266(_forward_impl)
#       353    0.014    0.000    0.014    0.000 {built-in method torch.tanh}
#    299737    0.013    0.000    0.013    0.000 {method 'append' of 'list' objects}
#    113070    0.013    0.000    0.020    0.000 {method 'add' of 'set' objects}
#       420    0.013    0.000   12.755    0.030 optimizer.py:368(wrapper)
#       420    0.013    0.000   12.708    0.030 optimizer.py:58(_use_grad)
#     61478    0.012    0.000    0.017    0.000 __init__.py:36(__get__)
#     55090    0.012    0.000    0.014    0.000 module.py:2224(<lambda>)
#     11078    0.011    0.000    0.011    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#      1430    0.011    0.000    0.041    0.000 {built-in method torch.tensor}
#     57960    0.010    0.000    0.010    0.000 {method 'conj' of 'torch._C.TensorBase' objects}
#      1120    0.010    0.000    0.010    0.000 {built-in method torch.flatten}
#       353    0.010    0.000    0.010    0.000 {built-in method torch.randn}
# 151940/145694    0.009    0.000    0.011    0.000 {built-in method builtins.len}
#      9920    0.009    0.000    0.019    0.000 series.py:992(__getitem__)
#      1120    0.008    0.000    0.010    0.000 utils.py:33(_list_with_default)
#        32    0.008    0.000    0.009    0.000 {built-in method matplotlib._image.resample}
# 31112/22200    0.008    0.000    0.013    0.000 artist.py:319(stale)
#    187606    0.008    0.000    0.008    0.000 {built-in method builtins.id}
#     61478    0.008    0.000    0.008    0.000 {built-in method torch._C._has_torch_function_variadic}
#     58380    0.007    0.000    0.179    0.000 module.py:2171(parameters)
#     66065    0.007    0.000    0.007    0.000 {method 'dim' of 'torch._C.TensorBase' objects}
#       576    0.007    0.000    0.037    0.000 text.py:363(_get_layout)
#      2824    0.007    0.000    0.230    0.000 conv.py:940(forward)
#     58380    0.007    0.000    0.171    0.000 module.py:2196(named_parameters)
#     35594    0.007    0.000    0.018    0.000 {built-in method builtins.getattr}
#       146    0.007    0.000    0.007    0.000 {built-in method torch.stack}
#       703    0.006    0.000    0.006    0.000 {method 'view' of 'torch._C.TensorBase' objects}
#     11431    0.006    0.000    0.011    0.000 container.py:207(__iter__)
#        10    0.006    0.001    0.006    0.001 serialization.py:461(__init__)
#       770    0.006    0.000    0.057    0.000 __init__.py:59(_make_grads)
#       350    0.006    0.000    0.034    0.000 functional.py:1495(norm)
#        74    0.006    0.000    0.103    0.001 load.py:123(__iter__)
#    117971    0.006    0.000    0.006    0.000 _jit_internal.py:1120(is_scripting)
# 12746/10026    0.005    0.000    0.037    0.000 {built-in method numpy.core._multiarray_umath.implement_array_function}
#       494    0.005    0.000    0.005    0.000 {built-in method torch._ops.profiler.}
#       353    0.005    0.000    5.663    0.016 3754520587.py:13(forward)
#      3964    0.005    0.000    0.007    0.000 font_manager.py:633(__hash__)
#    116760    0.005    0.000    0.005    0.000 _utils.py:869(is_compiling)
#     61478    0.005    0.000    0.005    0.000 {built-in method torch._C._get_cudnn_enabled}
#     58380    0.005    0.000    0.007    0.000 adam.py:301(<genexpr>)
#       384    0.005    0.000    0.036    0.000 ticker.py:2074(_raw_ticks)
#    111278    0.005    0.000    0.005    0.000 {method 'items' of 'collections.OrderedDict' objects}
#     59602    0.005    0.000    0.005    0.000 {built-in method torch._C._has_torch_function_unary}
#      1240    0.005    0.000    0.081    0.000 2540705727.py:19(__getitem__)
#       420    0.005    0.000   86.188    0.205 __init__.py:164(backward)
#       350    0.004    0.000    3.657    0.010 __init__.py:277(grad)
#     57960    0.004    0.000    0.004    0.000 {built-in method math.sqrt}
#     15965    0.004    0.000    0.008    0.000 serialization.py:790(persistent_id)
#       350    0.004    0.000    0.004    0.000 {built-in method torch.rand}
#       494    0.004    0.000    0.010    0.000 profiler.py:610(__exit__)
#      6248    0.004    0.000    0.009    0.000 copy.py:66(copy)
#       353    0.004    0.000    4.797    0.014 functional.py:3829(interpolate)
# 17667/17665    0.004    0.000    0.004    0.000 {built-in method builtins.iter}
#      1326    0.004    0.000    0.016    0.000 artist.py:1180(_update_props)
#      2733    0.004    0.000    0.015    0.000 {built-in method builtins.all}
#  6536/118    0.004    0.000    0.008    0.000 copy.py:128(deepcopy)
#       420    0.004    0.000   86.192    0.205 _tensor.py:463(backward)
#        16    0.004    0.000    0.024    0.002 image.py:328(_make_image)
#     15811    0.003    0.000    0.008    0.000 __init__.py:729(__getitem__)
#       192    0.003    0.000    0.135    0.001 axis.py:1269(_update_ticks)
#      1120    0.003    0.000    0.070    0.000 functional.py:1221(adaptive_avg_pool2d)
#      2735    0.003    0.000    0.007    0.000 transforms.py:754(__init__)
#       494    0.003    0.000    0.006    0.000 profiler.py:593(__init__)
#       384    0.003    0.000    0.010    0.000 ticker.py:778(_set_format)
#      5020    0.003    0.000    0.009    0.000 fromnumeric.py:69(_wrapreduction)
#        74    0.003    0.000    0.080    0.001 basics.py:224(chunked)
#       420    0.003    0.000   12.691    0.030 adam.py:133(step)
#     11160    0.003    0.000    0.004    0.000 indexing.py:2609(check_dict_or_set_indexers)
#       770    0.003    0.000    0.003    0.000 {method 'reshape' of 'torch._C.TensorBase' objects}
#       840    0.003    0.000    0.003    0.000 optimizer.py:122(<genexpr>)
#       420    0.003    0.000    0.007    0.000 optimizer.py:109(_default_to_fused_or_foreach)
#       124    0.003    0.000    0.003    0.000 {method 'set_text' of 'matplotlib.ft2font.FT2Font' objects}
#       844    0.003    0.000    0.004    0.000 typing.py:255(inner)
#       494    0.003    0.000    0.020    0.000 profiler.py:604(__enter__)
#      3828    0.003    0.000    0.004    0.000 __init__.py:2004(_setattr_cm)
#     15811    0.003    0.000    0.004    0.000 __init__.py:678(_get)
#        10    0.003    0.000    0.018    0.002 {method 'dump' of '_pickle.Pickler' objects}
#      1240    0.003    0.000    0.026    0.000 frame.py:3639(_ixs)
#      6773    0.003    0.000    0.003    0.000 __init__.py:101(check_in_list)
#      7885    0.003    0.000    0.003    0.000 {built-in method numpy.asarray}
#       726    0.003    0.000    0.006    0.000 _tensor.py:247(_reduce_ex_internal)
#      6162    0.003    0.000    0.003    0.000 {method 'copy' of 'numpy.ndarray' objects}
#      3752    0.002    0.000    0.005    0.000 __init__.py:890(get_siblings)
#      4945    0.002    0.000    0.002    0.000 {built-in method numpy.array}
#       560    0.002    0.000    0.044    0.000 text.py:918(get_window_extent)
#       420    0.002    0.000   12.571    0.030 adam.py:258(adam)
#      1137    0.002    0.000    0.004    0.000 __init__.py:1736(normalize_kwargs)
#       860    0.002    0.000    0.004    0.000 grad_mode.py:183(__init__)
# 1600/1176    0.002    0.000    0.008    0.000 transforms.py:2444(get_affine)
#        11    0.002    0.000    0.002    0.000 {method 'cpu' of 'torch._C.TensorBase' objects}
#      1240    0.002    0.000    0.035    0.000 indexing.py:1623(_getitem_axis)
#      2144    0.002    0.000    0.007    0.000 copy.py:258(_reconstruct)
#       432    0.002    0.000    0.015    0.000 lines.py:728(draw)
#      6176    0.002    0.000    0.003    0.000 transforms.py:1772(__init__)
#      1240    0.002    0.000    0.003    0.000 generic.py:5931(__finalize__)
#     13640    0.002    0.000    0.004    0.000 series.py:718(_values)
# 2876/2868    0.002    0.000    0.004    0.000 __init__.py:301(process)
#     31168    0.002    0.000    0.002    0.000 artist.py:851(get_animated)
#        79    0.002    0.000    0.002    0.000 {method 'acquire' of '_thread.lock' objects}
#  1050/350    0.002    0.000    0.003    0.000 symbolic_shapes.py:328(sym_eq)
#      1240    0.002    0.000    0.006    0.000 blocks.py:2385(new_block)
#       400    0.002    0.000    0.027    0.000 text.py:738(draw)
#      4537    0.002    0.000    0.002    0.000 {built-in method _abc._abc_instancecheck}
#      1240    0.002    0.000    0.002    0.000 base.py:5109(__contains__)
#     13640    0.002    0.000    0.002    0.000 managers.py:2011(internal_values)
#     10046    0.002    0.000    0.002    0.000 transforms.py:110(__init__)
#      1248    0.002    0.000    0.002    0.000 transforms.py:2910(_interval_contains_close)
#      1800    0.002    0.000    0.008    0.000 _base.py:844(<dictcomp>)
#     31639    0.002    0.000    0.002    0.000 {method 'get' of 'dict' objects}
#       180    0.002    0.000    0.013    0.000 lines.py:274(__init__)
#       353    0.002    0.000    0.004    0.000 gan.py:60(forward)
#       384    0.002    0.000    0.005    0.000 ticker.py:744(_set_order_of_magnitude)
#      1240    0.002    0.000    0.009    0.000 managers.py:1027(fast_xs)
#      1120    0.002    0.000    0.071    0.000 pooling.py:1189(forward)
#      2824    0.002    0.000    0.005    0.000 utils.py:9(parse)
#        16    0.002    0.000    0.002    0.000 {method 'take' of 'numpy.ndarray' objects}
#      2759    0.002    0.000    0.004    0.000 transforms.py:1889(__init__)
#      3072    0.002    0.000    0.004    0.000 lines.py:1289(set_ydata)
#      4728    0.002    0.000    0.006    0.000 artist.py:103(_stale_axes_callback)
#      2480    0.002    0.000    0.007    0.000 generic.py:5975(__getattr__)
#       384    0.002    0.000    0.006    0.000 ticker.py:705(_compute_offset)
#      1120    0.002    0.000    0.064    0.000 linear.py:115(forward)
#      2480    0.002    0.000    0.005    0.000 generic.py:5991(__setattr__)
#      2824    0.002    0.000    0.007    0.000 conv.py:629(_output_padding)
#    1192/4    0.002    0.000    0.206    0.051 artist.py:54(draw_wrapper)
#     13847    0.002    0.000    0.002    0.000 {method 'values' of 'collections.OrderedDict' objects}
#       722    0.002    0.000    0.168    0.000 storage.py:132(cpu)
#      1364    0.002    0.000    0.002    0.000 transforms.py:194(set_children)
#       350    0.002    0.000    0.137    0.000 1715469425.py:1(random_G_batch_vector_input)
#       964    0.001    0.000    0.001    0.000 {method 'round' of 'numpy.ndarray' objects}
#     15851    0.001    0.000    0.001    0.000 {function RcParams.__getitem__ at 0x137f2aaf0}
#       860    0.001    0.000    0.001    0.000 {built-in method torch._C._set_grad_enabled}
#       400    0.001    0.000    0.002    0.000 transforms.py:2830(nonsingular)
#       700    0.001    0.000    0.034    0.000 _tensor.py:34(wrapped)
#       426    0.001    0.000    0.003    0.000 artist.py:180(__init__)
#       204    0.001    0.000    0.006    0.000 lines.py:656(recache)
#       676    0.001    0.000    0.007    0.000 font_manager.py:590(__init__)
#      2476    0.001    0.000    0.003    0.000 transforms.py:1851(transform_affine)
#      5968    0.001    0.000    0.002    0.000 {built-in method builtins.any}
#       420    0.001    0.000    0.002    0.000 optimizer.py:321(_cuda_graph_capture_health_check)
#      2274    0.001    0.000    0.002    0.000 contextlib.py:82(__init__)
#        63    0.001    0.000    0.001    0.000 {method 'draw_path' of 'matplotlib.backends._backend_agg.RendererAgg' objects}
#      1240    0.001    0.000    0.002    0.000 generic.py:265(__init__)
#      1112    0.001    0.000    0.012    0.000 transforms.py:1475(transform)
# 2536/1608    0.001    0.000    0.002    0.000 transforms.py:167(_invalidate_internal)
#      1240    0.001    0.000    0.008    0.000 series.py:368(__init__)
#       350    0.001    0.000    0.035    0.000 _tensor.py:728(norm)
#     25234    0.001    0.000    0.001    0.000 {method 'items' of 'dict' objects}
#       192    0.001    0.000    0.003    0.000 numeric.py:2359(within_tol)
# 9959/7327    0.001    0.000    0.006    0.000 {built-in method builtins.hash}
#     11160    0.001    0.000    0.002    0.000 common.py:367(apply_if_callable)
#       904    0.001    0.000    0.007    0.000 axis.py:516(update_position)
#       796    0.001    0.000    0.005    0.000 transforms.py:1780(__eq__)
#      2561    0.001    0.000    0.010    0.000 fromnumeric.py:51(_wrapfunc)
#      1120    0.001    0.000    0.054    0.000 pooling.py:630(forward)
# 6001/5409    0.001    0.000    0.104    0.000 {built-in method builtins.next}
#      2476    0.001    0.000    0.001    0.000 {built-in method matplotlib._path.affine_transform}
#       733    0.001    0.000    0.001    0.000 {method 'detach' of 'torch._C.TensorBase' objects}
#        10    0.001    0.000    0.001    0.000 serialization.py:475(__exit__)
#      1240    0.001    0.000    0.037    0.000 indexing.py:1089(__getitem__)
#       668    0.001    0.000    0.002    0.000 transforms.py:1986(rotate)
#       192    0.001    0.000    0.030    0.000 axis.py:1498(get_minorticklocs)
#      1152    0.001    0.000    0.014    0.000 text.py:93(_get_text_metrics_with_cache)
#       800    0.001    0.000    0.002    0.000 _methods.py:93(_clip_dep_is_scalar_nan)
#      1800    0.001    0.000    0.009    0.000 _base.py:841(_unstale_viewLim)
#      1137    0.001    0.000    0.001    0.000 __init__.py:1775(<dictcomp>)
#      1572    0.001    0.000    0.003    0.000 lines.py:1268(set_xdata)
#      1240    0.001    0.000    0.002    0.000 base.py:767(__iter__)
#      1120    0.001    0.000    0.001    0.000 utils.py:41(<listcomp>)
#      1197    0.001    0.000    0.006    0.000 fromnumeric.py:38(_wrapit)
#     15239    0.001    0.000    0.001    0.000 __init__.py:604(is_storage)
#      3760    0.001    0.000    0.001    0.000 __init__.py:841(clean)
#      1119    0.001    0.000    0.002    0.000 __init__.py:65(check_isinstance)
#       420    0.001    0.000    0.006    0.000 transforms.py:474(transformed)
#     15080    0.001    0.000    0.001    0.000 artist.py:295(axes)
#      5020    0.001    0.000    0.001    0.000 fromnumeric.py:70(<dictcomp>)
#       108    0.001    0.000    0.001    0.000 {method 'draw_markers' of 'matplotlib.backends._backend_agg.RendererAgg' objects}
#       908    0.001    0.000    0.002    0.000 font_manager.py:809(set_size)
#       494    0.001    0.000    0.017    0.000 _ops.py:750(__call__)
#      4537    0.001    0.000    0.003    0.000 abc.py:96(__instancecheck__)
#      1120    0.001    0.000   15.833    0.014 resnet.py:284(forward)
#      5400    0.001    0.000    0.001    0.000 function_base.py:346(iterable)
#       384    0.001    0.000    0.001    0.000 ticker.py:1899(scale_range)
#         1    0.001    0.001  127.626  127.626 <string>:1(<module>)
#      1452    0.001    0.000    0.001    0.000 storage.py:498(__new__)
#        96    0.001    0.000    0.060    0.001 spines.py:142(get_window_extent)
#      1237    0.001    0.000    0.081    0.000 dataset.py:388(__getitem__)
#       432    0.001    0.000    0.002    0.000 transforms.py:624(translated)
# 3000/1424    0.001    0.000    0.001    0.000 transforms.py:2413(<lambda>)
#       368    0.001    0.000    0.001    0.000 {built-in method torch.zeros_like}
#   442/118    0.001    0.000    0.008    0.000 copy.py:226(_deepcopy_dict)
#      4420    0.001    0.000    0.001    0.000 {built-in method numpy.asanyarray}
#       400    0.001    0.000    0.001    0.000 _methods.py:108(_clip_dep_invoke_with_casting)
#        16    0.001    0.000    0.004    0.000 colors.py:683(__call__)
#        60    0.001    0.000    0.029    0.000 axis.py:58(__init__)
# 2274/2126    0.001    0.000    0.005    0.000 contextlib.py:117(__exit__)
#       192    0.001    0.000    0.011    0.000 axis.py:2523(get_tick_space)
#       384    0.001    0.000    0.008    0.000 transforms.py:1421(__sub__)
#      1240    0.001    0.000    0.005    0.000 base.py:5212(_can_hold_identifiers_and_holds_name)
#       244    0.001    0.000    0.009    0.000 text.py:185(_reset_visual_defaults)
#       388    0.001    0.000    0.003    0.000 backend_bases.py:760(__init__)
#      2836    0.001    0.000    0.005    0.000 artist.py:417(pchanged)
#      1240    0.001    0.000    0.003    0.000 indexing.py:1571(_validate_integer)
#      1011    0.001    0.000    0.001    0.000 {built-in method builtins.sorted}
#      1240    0.001    0.000    0.001    0.000 blocks.py:2305(maybe_coerce_values)
#      1240    0.001    0.000    0.001    0.000 blocks.py:892(iget)
#       192    0.001    0.000    0.011    0.000 axis.py:2782(get_tick_space)
#      2609    0.001    0.000    0.001    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#       772    0.001    0.000    0.002    0.000 transforms.py:2355(__init__)
#      1240    0.001    0.000    0.001    0.000 generic.py:523(_get_axis)
#      1248    0.001    0.000    0.003    0.000 ticker.py:568(__call__)
#      1646    0.001    0.000    0.003    0.000 colors.py:265(to_rgba)
#      6722    0.001    0.000    0.001    0.000 transforms.py:1039(get_points)
#      2480    0.001    0.000    0.001    0.000 {pandas._libs.lib.is_list_like}
#       408    0.001    0.000    0.011    0.000 markers.py:327(_set_marker)
#      4184    0.001    0.000    0.002    0.000 figure.py:68(_stale_figure_callback)
#      2174    0.001    0.000    0.003    0.000 colors.py:213(_is_nth_color)
#      2165    0.001    0.000    0.002    0.000 re.py:188(match)
#      1240    0.001    0.000    0.001    0.000 blocks.py:2401(check_ndim)
#      1928    0.001    0.000    0.001    0.000 {method '__reduce_ex__' of 'object' objects}
#      2480    0.001    0.000    0.002    0.000 base.py:46(__len__)
#      2274    0.001    0.000    0.002    0.000 contextlib.py:238(helper)
#       514    0.001    0.000    0.001    0.000 transforms.py:2054(scale)
#       494    0.001    0.000    0.001    0.000 typing.py:329(__hash__)
#      1240    0.001    0.000    0.001    0.000 blocks.py:2334(get_block_type)
#      7200    0.001    0.000    0.001    0.000 _base.py:845(<genexpr>)
#       404    0.001    0.000    0.004    0.000 axis.py:455(update_position)
#      3720    0.001    0.000    0.001    0.000 generic.py:37(_check)
#      2234    0.001    0.000    0.001    0.000 enum.py:313(__call__)
# 2274/2126    0.001    0.000    0.006    0.000 contextlib.py:108(__enter__)
#      1452    0.001    0.000    0.001    0.000 storage.py:570(__init__)
#       172    0.001    0.000    0.001    0.000 inspect.py:2901(_bind)
#     366/4    0.001    0.000    0.002    0.001 module.py:1824(state_dict)
#     12400    0.001    0.000    0.001    0.000 {pandas._libs.lib.is_integer}
#      1850    0.001    0.000    0.004    0.000 fromnumeric.py:2829(amin)
#       144    0.001    0.000    0.007    0.000 collate.py:155(collate_tensor_fn)
#      1240    0.001    0.000    0.002    0.000 series.py:671(name)
#      3016    0.001    0.000    0.004    0.000 {method 'max' of 'numpy.ndarray' objects}
#       350    0.001    0.000    0.016    0.000 _tensor.py:939(__rsub__)
#      1536    0.001    0.000    0.011    0.000 axis.py:2253(getter)
#      1608    0.001    0.000    0.002    0.000 transforms.py:157(invalidate)
#      1240    0.001    0.000    0.002    0.000 common.py:158(is_object_dtype)
#      1240    0.001    0.000    0.001    0.000 series.py:621(name)
#      1138    0.001    0.000    0.001    0.000 load.py:121(<genexpr>)
#      3720    0.001    0.000    0.002    0.000 generic.py:42(_instancecheck)
#       497    0.001    0.000    0.001    0.000 __init__.py:197(__init__)
#       384    0.001    0.000    0.005    0.000 axis.py:1565(_get_tick_label_size)
#       720    0.001    0.000    0.001    0.000 text.py:1283(_preprocess_math)
#      1874    0.001    0.000    0.004    0.000 fromnumeric.py:2703(amax)
#      1240    0.001    0.000    0.003    0.000 common.py:95(is_bool_indexer)
#       420    0.001    0.000    0.001    0.000 {built-in method torch._C._are_functorch_transforms_active}
#      1000    0.001    0.000    0.001    0.000 {built-in method _abc._abc_subclasscheck}
#      5444    0.001    0.000    0.001    0.000 transforms.py:1929(get_matrix)
#      2480    0.001    0.000    0.001    0.000 managers.py:280(arrays)
#       108    0.001    0.000    0.001    0.000 {method 'draw_glyphs_to_bitmap' of 'matplotlib.ft2font.FT2Font' objects}
#       805    0.001    0.000    0.005    0.000 transforms.py:809(from_extents)
#      1136    0.001    0.000    0.077    0.000 load.py:167(do_item)
#     13889    0.001    0.000    0.001    0.000 {built-in method builtins.callable}
#       400    0.001    0.000    0.004    0.000 _methods.py:127(_clip)
#      1600    0.001    0.000    0.007    0.000 font_manager.py:894(copy)
#       384    0.001    0.000    0.039    0.000 ticker.py:2138(tick_values)
#      2480    0.001    0.000    0.002    0.000 base.py:162(array)
#       494    0.001    0.000    0.006    0.000 _ops.py:512(__call__)
#       989    0.001    0.000    0.016    0.000 artist.py:1227(set)
#      3223    0.001    0.000    0.001    0.000 {built-in method builtins.max}
#      5795    0.001    0.000    0.001    0.000 {built-in method builtins.issubclass}
#        10    0.001    0.000    0.502    0.050 serialization.py:575(save)
#      2173    0.001    0.000    0.001    0.000 re.py:289(_compile)
#      6087    0.001    0.000    0.001    0.000 {built-in method builtins.hasattr}
#      1240    0.001    0.000    0.001    0.000 range.py:902(__getitem__)
#      1112    0.001    0.000    0.009    0.000 transforms.py:2421(transform_affine)
#      1136    0.001    0.000    0.076    0.000 load.py:174(create_item)
#      1600    0.001    0.000    0.002    0.000 <__array_function__ internals>:177(dot)
#      3155    0.001    0.000    0.001    0.000 {built-in method builtins.setattr}
#         4    0.001    0.000    0.001    0.000 encoder.py:204(iterencode)
#      2368    0.001    0.000    0.004    0.000 transforms.py:1785(transform)
#       400    0.001    0.000    0.001    0.000 getlimits.py:558(smallest_normal)
#       420    0.001    0.000    0.001    0.000 _foreach_utils.py:12(_get_fused_kernels_supported_devices)
#      9920    0.001    0.000    0.001    0.000 {pandas._libs.lib.is_scalar}
#      1248    0.001    0.000    0.002    0.000 ticker.py:516(_format_maybe_minus_and_locale)
#       193    0.001    0.000    0.012    0.000 transforms.py:649(union)
#       384    0.001    0.000    0.022    0.000 ticker.py:696(set_locs)
#        84    0.001    0.000    0.003    0.000 patches.py:533(_draw_paths_with_artist_properties)
#       108    0.001    0.000    0.001    0.000 {method 'draw_text_image' of 'matplotlib.backends._backend_agg.RendererAgg' objects}
#      1850    0.001    0.000    0.005    0.000 <__array_function__ internals>:177(amin)
#      1784    0.001    0.000    0.010    0.000 _base.py:855(viewLim)
#       770    0.001    0.000    0.001    0.000 __init__.py:154(_tensor_or_tensors_to_tuple)
#       932    0.001    0.000    0.003    0.000 transforms.py:2511(composite_transform_factory)
#      1192    0.001    0.000    0.003    0.000 fromnumeric.py:2432(all)
#      2165    0.001    0.000    0.001    0.000 {method 'match' of 're.Pattern' objects}
#       900    0.001    0.000    0.001    0.000 __init__.py:1324(is_math_text)
#       350    0.001    0.000    0.001    0.000 {built-in method _functools.reduce}
#      1874    0.001    0.000    0.005    0.000 <__array_function__ internals>:177(amax)
#      3016    0.001    0.000    0.003    0.000 _methods.py:39(_amax)
#      2280    0.001    0.000    0.001    0.000 text.py:1206(set_y)
#       726    0.001    0.000    0.002    0.000 _tensor.py:241(_typed_storage)
#      1240    0.001    0.000    0.001    0.000 common.py:1494(_is_dtype_type)
#       192    0.001    0.000    0.005    0.000 numeric.py:2278(isclose)
#        70    0.000    0.000    0.000    0.000 {built-in method torch.unsqueeze}
#      1192    0.000    0.000    0.004    0.000 <__array_function__ internals>:177(all)
#       416    0.000    0.000    0.001    0.000 _ufunc_config.py:33(seterr)
#       384    0.000    0.000    0.003    0.000 ticker.py:218(<listcomp>)
#      2645    0.000    0.000    0.000    0.000 {method 'update' of 'dict' objects}
#       366    0.000    0.000    0.002    0.000 module.py:1785(_save_to_state_dict)
#       257    0.000    0.000    0.001    0.000 {method 'astype' of 'numpy.ndarray' objects}
#      3752    0.000    0.000    0.000    0.000 __init__.py:894(<listcomp>)
#       350    0.000    0.000    0.002    0.000 typing.py:802(__getitem__)
#         1    0.000    0.000  127.627  127.627 {built-in method builtins.exec}
#       332    0.000    0.000    0.002    0.000 path.py:99(__init__)
#      1928    0.000    0.000    0.001    0.000 copyreg.py:90(__newobj__)
#      1672    0.000    0.000    0.003    0.000 {method 'min' of 'numpy.ndarray' objects}
#        74    0.000    0.000    0.097    0.001 dataloader.py:626(__next__)
#       676    0.000    0.000    0.001    0.000 font_manager.py:731(set_style)
#       216    0.000    0.000    0.001    0.000 shape_base.py:612(column_stack)
#       384    0.000    0.000    0.001    0.000 _methods.py:281(_ptp)
#      1240    0.000    0.000    0.000    0.000 flags.py:49(__init__)
#       332    0.000    0.000    0.001    0.000 __init__.py:134(check_shape)
#      1296    0.000    0.000    0.001    0.000 ticker.py:247(fix_minus)
#       384    0.000    0.000    0.043    0.000 ticker.py:2134(__call__)
#       360    0.000    0.000    0.002    0.000 basics.py:59(listify)
#      4432    0.000    0.000    0.000    0.000 {built-in method builtins.abs}
#      1712    0.000    0.000    0.001    0.000 scale.py:115(get_transform)
#       108    0.000    0.000    0.004    0.000 path.py:603(get_extents)
#        12    0.000    0.000    0.000    0.000 {method 'draw_image' of 'matplotlib.backends._backend_agg.RendererAgg' objects}
#      1112    0.000    0.000    0.001    0.000 transforms.py:2425(transform_non_affine)
#      3076    0.000    0.000    0.000    0.000 text.py:1265(set_text)
#        70    0.000    0.000    0.000    0.000 {method 'permute' of 'torch._C.TensorBase' objects}
#       108    0.000    0.000    0.007    0.000 backend_agg.py:200(draw_text)
#       708    0.000    0.000    0.002    0.000 markers.py:277(_recache)
#       668    0.000    0.000    0.003    0.000 transforms.py:2009(rotate_deg)
#       180    0.000    0.000    0.001    0.000 artist.py:1159(update_from)
#    216/72    0.000    0.000    0.009    0.000 load.py:48(fa_collate)
#      3605    0.000    0.000    0.000    0.000 artist.py:847(get_visible)
#        24    0.000    0.000    0.006    0.000 _base.py:2937(_update_title_position)
#       780    0.000    0.000    0.003    0.000 transforms.py:328(ymax)
#       120    0.000    0.000    0.000    0.000 function_base.py:1320(diff)
#       560    0.000    0.000    0.001    0.000 text.py:893(get_unitless_position)
#      2480    0.000    0.000    0.001    0.000 common.py:1650(<genexpr>)
#        92    0.000    0.000    0.003    0.000 patches.py:742(get_patch_transform)
#    216/72    0.000    0.000    0.004    0.000 dispatch.py:197(retain_types)
#       989    0.000    0.000    0.016    0.000 artist.py:147(<lambda>)
#       160    0.000    0.000    0.001    0.000 spines.py:227(_adjust_location)
#      1248    0.000    0.000    0.002    0.000 axis.py:305(set_label1)
#       144    0.000    0.000    0.043    0.000 axis.py:293(draw)
#      2088    0.000    0.000    0.001    0.000 transforms.py:2134(transform)
#      1080    0.000    0.000    0.001    0.000 __init__.py:1337(_to_unmasked_float_array)
#   256/240    0.000    0.000    0.001    0.000 spines.py:332(get_spine_transform)
#       804    0.000    0.000    0.001    0.000 fromnumeric.py:3152(ndim)
#      4362    0.000    0.000    0.000    0.000 {built-in method __new__ of type object at 0x10472b828}
#      2480    0.000    0.000    0.001    0.000 base.py:875(__len__)
#      1240    0.000    0.000    0.002    0.000 common.py:1631(validate_all_hashable)
#      1240    0.000    0.000    0.000    0.000 flags.py:85(allows_duplicate_labels)
#       884    0.000    0.000    0.001    0.000 transforms.py:343(intervalx)
#       684    0.000    0.000    0.003    0.000 transforms.py:313(xmin)
#      2234    0.000    0.000    0.000    0.000 enum.py:631(__new__)
#       756    0.000    0.000    0.002    0.000 transforms.py:318(ymin)
#       180    0.000    0.000    0.002    0.000 font_manager.py:1201(findfont)
#   376/353    0.000    0.000    0.029    0.000 deprecation.py:443(wrapper)
#       884    0.000    0.000    0.000    0.000 transforms.py:352(intervaly)
#       840    0.000    0.000    0.000    0.000 {built-in method torch._C._get_privateuse1_backend_name}
#        32    0.000    0.000    0.166    0.005 axis.py:1380(draw)
#      1316    0.000    0.000    0.005    0.000 font_manager.py:644(__eq__)
#       800    0.000    0.000    0.001    0.000 font_manager.py:717(set_family)
#      2480    0.000    0.000    0.003    0.000 series.py:783(__len__)
#       676    0.000    0.000    0.001    0.000 font_manager.py:744(set_variant)
#       416    0.000    0.000    0.000    0.000 _ufunc_config.py:132(geterr)
#      1248    0.000    0.000    0.002    0.000 axis.py:318(set_label2)
#         2    0.000    0.000    0.000    0.000 backend_agg.py:78(__init__)
#       540    0.000    0.000    0.001    0.000 lines.py:1195(_set_markercolor)
#       353    0.000    0.000    0.015    0.000 activation.py:355(forward)
#       350    0.000    0.000    0.000    0.000 typing.py:720(__hash__)
#       932    0.000    0.000    0.003    0.000 transforms.py:1343(__add__)
#       964    0.000    0.000    0.004    0.000 <__array_function__ internals>:177(round_)
#       216    0.000    0.000    0.002    0.000 foundation.py:104(__init__)
#       726    0.000    0.000    0.007    0.000 _tensor.py:212(__reduce_ex__)
#       805    0.000    0.000    0.003    0.000 <__array_function__ internals>:177(reshape)
#       684    0.000    0.000    0.002    0.000 transforms.py:323(xmax)
#       726    0.000    0.000    0.001    0.000 serialization.py:380(location_tag)
#      1520    0.000    0.000    0.001    0.000 axis.py:770(get_transform)
#       706    0.000    0.000    0.000    0.000 functional.py:3790(_is_integer)
#      1290    0.000    0.000    0.000    0.000 {built-in method torch.is_grad_enabled}
#        96    0.000    0.000    0.041    0.000 axis.py:1316(<listcomp>)
#       216    0.000    0.000    0.002    0.000 foundation.py:96(__call__)
#       448    0.000    0.000    0.001    0.000 path.py:162(_fast_from_codes_and_verts)
#      1132    0.000    0.000    0.000    0.000 artist.py:451(get_transform)
#      1240    0.000    0.000    0.000    0.000 construction.py:458(ensure_wrapped_if_datetimelike)
#      1672    0.000    0.000    0.002    0.000 _methods.py:43(_amin)
#        32    0.000    0.000    0.011    0.000 image.py:160(_resample)
#       156    0.000    0.000    0.001    0.000 core.py:2940(_update_from)
#       204    0.000    0.000    0.000    0.000 stride_tricks.py:416(_broadcast_shape)
#      1172    0.000    0.000    0.000    0.000 copy.py:242(_keep_alive)
#       304    0.000    0.000    0.001    0.000 transforms.py:1615(transform_path_non_affine)
#      1280    0.000    0.000    0.001    0.000 text.py:1195(set_x)
#      3760    0.000    0.000    0.000    0.000 __init__.py:844(<listcomp>)
#       964    0.000    0.000    0.003    0.000 <__array_function__ internals>:177(around)
#        29    0.000    0.000    0.000    0.000 socket.py:621(send)
#       384    0.000    0.000    0.015    0.000 ticker.py:215(format_ticks)
#      1050    0.000    0.000    0.000    0.000 overrides.py:1823(is_tensor_like)
#       332    0.000    0.000    0.001    0.000 path.py:202(_update_values)
#       709    0.000    0.000    0.005    0.000 transforms.py:800(from_bounds)
#       156    0.000    0.000    0.001    0.000 core.py:2966(__array_finalize__)
#      1178    0.000    0.000    0.014    0.000 artist.py:1216(_internal_update)
#      1059    0.000    0.000    0.001    0.000 functional.py:3941(<genexpr>)
#       408    0.000    0.000    0.001    0.000 markers.py:302(_set_fillstyle)
#       180    0.000    0.000    0.001    0.000 lines.py:1136(set_linestyle)
#       421    0.000    0.000    0.000    0.000 {method 'numel' of 'torch._C.TensorBase' objects}
#       350    0.000    0.000    0.001    0.000 _VF.py:26(__getattr__)
#      1240    0.000    0.000    0.000    0.000 __init__.py:33(using_copy_on_write)
#       408    0.000    0.000    0.012    0.000 markers.py:228(__init__)
#       964    0.000    0.000    0.002    0.000 fromnumeric.py:3245(around)
#      1536    0.000    0.000    0.001    0.000 transforms.py:1358(_iter_break_from_left_to_right)
#      3964    0.000    0.000    0.000    0.000 font_manager.py:678(get_weight)
#      2582    0.000    0.000    0.000    0.000 {method 'pop' of 'dict' objects}
#       348    0.000    0.000    0.002    0.000 text.py:985(set_color)
#       384    0.000    0.000    0.001    0.000 fromnumeric.py:2604(ptp)
#       384    0.000    0.000    0.000    0.000 {built-in method numpy.arange}
#       700    0.000    0.000    0.000    0.000 __init__.py:359(<genexpr>)
#      1240    0.000    0.000    0.000    0.000 range.py:892(__len__)
#       720    0.000    0.000    0.000    0.000 text.py:687(_get_wrapped_text)
#      4472    0.000    0.000    0.000    0.000 font_manager.py:695(get_size)
#        56    0.000    0.000    0.001    0.000 pathlib.py:64(parse_parts)
#        96    0.000    0.000    0.001    0.000 core.py:2808(__new__)
#       726    0.000    0.000    0.000    0.000 _utils.py:834(_element_size)
#       804    0.000    0.000    0.001    0.000 <__array_function__ internals>:177(ndim)
#       732    0.000    0.000    0.001    0.000 font_manager.py:757(set_weight)
#      1240    0.000    0.000    0.000    0.000 managers.py:1847(__init__)
#       578    0.000    0.000    0.001    0.000 typing.py:771(__subclasscheck__)
#       964    0.000    0.000    0.003    0.000 fromnumeric.py:3754(round_)
#         2    0.000    0.000    0.000    0.000 {method 'copy' of 'ImagingCore' objects}
#      2578    0.000    0.000    0.000    0.000 figure.py:2768(_get_dpi)
#       805    0.000    0.000    0.002    0.000 fromnumeric.py:198(reshape)
#      1080    0.000    0.000    0.001    0.000 font_manager.py:1257(<genexpr>)
#        48    0.000    0.000    0.013    0.000 axis.py:867(clear)
#      4088    0.000    0.000    0.000    0.000 font_manager.py:650(get_family)
#      2480    0.000    0.000    0.000    0.000 managers.py:292(<listcomp>)
#      1240    0.000    0.000    0.000    0.000 indexing.py:148(iloc)
#      2480    0.000    0.000    0.000    0.000 managers.py:233(items)
#      1240    0.000    0.000    0.000    0.000 generic.py:509(_get_axis_number)
#       476    0.000    0.000    0.001    0.000 text.py:1249(set_verticalalignment)
#      3824    0.000    0.000    0.000    0.000 {method 'values' of 'dict' objects}
#    168/88    0.000    0.000    0.002    0.000 deprecation.py:379(wrapper)
#      1800    0.000    0.000    0.000    0.000 {method 'count' of 'str' objects}
#       353    0.000    0.000    0.000    0.000 __init__.py:882(are_deterministic_algorithms_enabled)
#        36    0.000    0.000    0.003    0.000 _base.py:1876(apply_aspect)
#   323/319    0.000    0.000    0.001    0.000 transforms.py:1109(get_points)
#       252    0.000    0.000    0.005    0.000 patches.py:262(get_transform)
#       204    0.000    0.000    0.001    0.000 stride_tricks.py:480(broadcast_arrays)
#       726    0.000    0.000    0.001    0.000 _utils.py:439(_get_obj_state)
#      1026    0.000    0.000    0.001    0.000 artist.py:271(convert_xunits)
#      1612    0.000    0.000    0.000    0.000 transforms.py:209(<lambda>)
#      1240    0.000    0.000    0.000    0.000 generic.py:599(_info_axis)
#       800    0.000    0.000    0.000    0.000 _methods.py:103(_clip_dep_is_byte_swapped)
#      1240    0.000    0.000    0.000    0.000 inference.py:328(is_hashable)
#       726    0.000    0.000    0.001    0.000 storage.py:919(_size)
#       465    0.000    0.000    0.001    0.000 artist.py:438(set_transform)
#        64    0.000    0.000    0.000    0.000 {built-in method numpy.zeros}
#      1240    0.000    0.000    0.001    0.000 generic.py:4153(_set_is_copy)
#      3924    0.000    0.000    0.000    0.000 copy.py:107(_copy_immutable)
#        40    0.000    0.000    0.025    0.001 axis.py:477(__init__)
#      3964    0.000    0.000    0.000    0.000 font_manager.py:666(get_style)
#       528    0.000    0.000    0.002    0.000 colors.py:237(_check_color_like)
#      3964    0.000    0.000    0.000    0.000 font_manager.py:672(get_variant)
#        48    0.000    0.000    0.045    0.001 axis.py:2128(_get_tick_boxes_siblings)
#      1532    0.000    0.000    0.000    0.000 transforms.py:2605(get_matrix)
#       768    0.000    0.000    0.000    0.000 ticker.py:1932(closeto)
#       124    0.000    0.000    0.000    0.000 font_manager.py:1493(get_font)
#      1086    0.000    0.000    0.001    0.000 artist.py:283(convert_yunits)
#      1000    0.000    0.000    0.001    0.000 abc.py:100(__subclasscheck__)
#        74    0.000    0.000    0.094    0.001 dataloader.py:673(_next_data)
#       488    0.000    0.000    0.002    0.000 transforms.py:790(unit)
#       528    0.000    0.000    0.002    0.000 colors.py:218(is_color_like)
#       400    0.000    0.000    0.000    0.000 getlimits.py:476(__new__)
#        56    0.000    0.000    0.003    0.000 axis.py:351(_apply_params)
#       216    0.000    0.000    0.000    0.000 {built-in method builtins.round}
#       360    0.000    0.000    0.002    0.000 lines.py:637(set_data)
#      3964    0.000    0.000    0.000    0.000 font_manager.py:687(get_stretch)
#        12    0.000    0.000    0.001    0.000 arraysetops.py:524(in1d)
#      1140    0.000    0.000    0.000    0.000 random.py:250(_randbelow_with_getrandbits)
#       425    0.000    0.000    0.001    0.000 artist.py:737(set_figure)
#       244    0.000    0.000    0.004    0.000 text.py:1307(set_fontproperties)
#       676    0.000    0.000    0.001    0.000 font_manager.py:783(set_stretch)
#      2480    0.000    0.000    0.000    0.000 generic.py:359(flags)
#       545    0.000    0.000    0.000    0.000 transforms.py:361(width)
#       400    0.000    0.000    0.005    0.000 fromnumeric.py:2111(clip)
#      3964    0.000    0.000    0.000    0.000 font_manager.py:859(get_math_fontfamily)
#       148    0.000    0.000    0.009    0.000 text.py:132(__init__)
#       720    0.000    0.000    0.000    0.000 text.py:315(get_rotation)
#         4    0.000    0.000    0.000    0.000 core.py:2332(masked_invalid)
#       476    0.000    0.000    0.000    0.000 text.py:1000(set_horizontalalignment)
#         1    0.000    0.000    0.204    0.204 backend_inline.py:72(show)
#       148    0.000    0.000    0.003    0.000 text.py:221(update)
#       124    0.000    0.000    0.002    0.000 font_manager.py:1271(_find_fonts_by_props)
#       420    0.000    0.000    0.000    0.000 __init__.py:30(is_built)
#      2384    0.000    0.000    0.000    0.000 artist.py:939(get_rasterized)
#      3964    0.000    0.000    0.000    0.000 font_manager.py:701(get_file)
#       112    0.000    0.000    0.001    0.000 axis.py:1870(_set_formatter)
#       420    0.000    0.000    0.000    0.000 _foreach_utils.py:8(_get_foreach_kernels_supported_devices)
#       384    0.000    0.000    0.000    0.000 ticker.py:1942(le)
#      1240    0.000    0.000    0.000    0.000 common.py:144(<lambda>)
#      1240    0.000    0.000    0.001    0.000 inference.py:189(is_array_like)
#       726    0.000    0.000    0.000    0.000 _utils.py:185(get_tensor_metadata)
#      5040    0.000    0.000    0.000    0.000 copy.py:182(_deepcopy_atomic)
#        16    0.000    0.000    0.001    0.000 colors.py:1315(__call__)
#       388    0.000    0.000    0.001    0.000 backend_bases.py:928(set_clip_path)
#       676    0.000    0.000    0.001    0.000 font_manager.py:867(set_math_fontfamily)
#        72    0.000    0.000    0.001    0.000 foundation.py:181(zip)
#        56    0.000    0.000    0.001    0.000 ticker.py:2010(_validate_steps)
#       576    0.000    0.000    0.001    0.000 transforms.py:2222(<lambda>)
#       108    0.000    0.000    0.009    0.000 lines.py:1334(update_from)
#       124    0.000    0.000    0.003    0.000 backend_agg.py:263(_prepare_font)
#       880    0.000    0.000    0.001    0.000 transforms.py:2262(get_affine)
#      1050    0.000    0.000    0.000    0.000 {built-in method torch._C._has_torch_function}
#       726    0.000    0.000    0.000    0.000 serialization.py:209(_cpu_tag)
#      1240    0.000    0.000    0.000    0.000 utils.py:64(is_list_like_indexer)
#   520/264    0.000    0.000    0.001    0.000 transforms.py:2384(_invalidate_internal)
#       296    0.000    0.000    0.005    0.000 artist.py:1233(_cm_set)
#       144    0.000    0.000    0.001    0.000 transforms.py:2759(_revalidate)
#       578    0.000    0.000    0.001    0.000 typing.py:768(__instancecheck__)
#      1032    0.000    0.000    0.000    0.000 __init__.py:1844(_str_equal)
#       461    0.000    0.000    0.002    0.000 artist.py:1048(set_visible)
#       122    0.000    0.000    0.000    0.000 transforms.py:379(bounds)
#       272    0.000    0.000    0.000    0.000 text.py:329(set_rotation_mode)
#       400    0.000    0.000    0.006    0.000 <__array_function__ internals>:177(clip)
#      2384    0.000    0.000    0.000    0.000 artist.py:966(get_agg_filter)
#        40    0.000    0.000    0.000    0.000 __init__.py:416(by_key)
#      2018    0.000    0.000    0.000    0.000 {method 'replace' of 'str' objects}
#      1240    0.000    0.000    0.000    0.000 common.py:1322(is_1d_only_ea_dtype)
#       144    0.000    0.000    0.002    0.000 foundation.py:111(_new)
#      1272    0.000    0.000    0.000    0.000 transforms.py:1761(<lambda>)
#        60    0.000    0.000    0.004    0.000 artist.py:778(set_clip_path)
#       144    0.000    0.000    0.000    0.000 transforms.py:2744(__init__)
#       996    0.000    0.000    0.000    0.000 __init__.py:154(<genexpr>)
#      2174    0.000    0.000    0.000    0.000 {method 'nbytes' of 'torch._C.StorageBase' objects}
#      2904    0.000    0.000    0.000    0.000 {method 'data_ptr' of 'torch._C.StorageBase' objects}
#        56    0.000    0.000    0.002    0.000 ticker.py:533(set_useMathText)
#       350    0.000    0.000    0.000    0.000 symbolic_shapes.py:581(expect_true)
#         2    0.000    0.000    0.001    0.000 random.py:315(sample)
#       384    0.000    0.000    0.000    0.000 ticker.py:1949(ge)
# ...
#         8    0.000    0.000    0.000    0.000 axis.py:840(_set_autoscale_on)
#         4    0.000    0.000    0.000    0.000 basics.py:488(_component_attr_filter)
#         2    0.000    0.000    0.000    0.000 fetch.py:8(__init__)
#         1    0.000    0.000    0.000    0.000 psnr.py:58(_psnr_input_check)
#         8    0.000    0.000    0.000    0.000 axis.py:836(_get_autoscale_on)
#        14    0.000    0.000    0.000    0.000 {method 'copy' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 pretty.py:313(flush)
#         2    0.000    0.000    0.000    0.000 __init__.py:835(__init__)
#         2    0.000    0.000    0.000    0.000 warnings.py:117(_formatwarnmsg)
#        16    0.000    0.000    0.000    0.000 backend_agg.py:297(option_scale_image)
#        16    0.000    0.000    0.000    0.000 backend_bases.py:449(get_image_magnification)
#         9    0.000    0.000    0.000    0.000 {method 'release' of '_thread.RLock' objects}
#         4    0.000    0.000    0.000    0.000 cm.py:84(__iter__)
#         3    0.000    0.000    0.000    0.000 backend_bases.py:2233(<dictcomp>)
#         4    0.000    0.000    0.000    0.000 gridspec.py:199(<listcomp>)
#        12    0.000    0.000    0.000    0.000 numeric.py:73(_zeros_like_dispatcher)
#         4    0.000    0.000    0.000    0.000 figure.py:94(bubble)
#         1    0.000    0.000    0.000    0.000 _pylab_helpers.py:118(set_active)
#         5    0.000    0.000    0.000    0.000 patches.py:768(rotation_point)
#        12    0.000    0.000    0.000    0.000 arraysetops.py:761(_isin_dispatcher)
#         1    0.000    0.000    0.000    0.000 backend_bases.py:3581(draw_if_interactive)
#         1    0.000    0.000    0.000    0.000 zmqshell.py:74(_hooks)
#         6    0.000    0.000    0.000    0.000 std.py:167(colour)
#         4    0.000    0.000    0.000    0.000 _base.py:652(<dictcomp>)
#         4    0.000    0.000    0.000    0.000 contextlib.py:697(__init__)
#         1    0.000    0.000    0.000    0.000 session.py:198(utcnow)
#         8    0.000    0.000    0.000    0.000 transforms.py:1760(<lambda>)
#         1    0.000    0.000    0.000    0.000 _pylab_helpers.py:100(get_active)
#         1    0.000    0.000    0.000    0.000 os.py:748(encode)
#         2    0.000    0.000    0.000    0.000 _weakrefset.py:20(__enter__)
#         2    0.000    0.000    0.000    0.000 pyplot.py:185(_get_required_interactive_framework)
#         4    0.000    0.000    0.000    0.000 backend_bases.py:2844(notify_axes_change)
#         8    0.000    0.000    0.000    0.000 {method 'isidentifier' of 'str' objects}
#         2    0.000    0.000    0.000    0.000 figure.py:459(set_edgecolor)
#         3    0.000    0.000    0.000    0.000 configurable.py:553(instance)
#         2    0.000    0.000    0.000    0.000 {method 'sort' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 session.py:281(extract_header)
#         4    0.000    0.000    0.000    0.000 {built-in method sys.exc_info}
#         2    0.000    0.000    0.000    0.000 functools.py:64(wraps)
#         1    0.000    0.000    0.000    0.000 pyplot.py:953(close)
#         2    0.000    0.000    0.000    0.000 load.py:120(sample)
#         1    0.000    0.000    0.000    0.000 session.py:645(msg_header)
#         1    0.000    0.000    0.000    0.000 backend_inline.py:231(_fetch_figure_metadata)
#         4    0.000    0.000    0.000    0.000 {method 'pop' of 'collections.OrderedDict' objects}
#        12    0.000    0.000    0.000    0.000 arraysetops.py:519(_in1d_dispatcher)
#         1    0.000    0.000    0.000    0.000 figure.py:3146(clear)
#        11    0.000    0.000    0.000    0.000 {method 'getvalue' of '_io.BytesIO' objects}
#         4    0.000    0.000    0.000    0.000 std.py:110(__enter__)
#         3    0.000    0.000    0.000    0.000 pretty.py:482(__init__)
#        10    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.lock' objects}
#         2    0.000    0.000    0.000    0.000 utils.py:186(disable_on_exception)
#         3    0.000    0.000    0.000    0.000 figure.py:431(get_facecolor)
#         2    0.000    0.000    0.000    0.000 figure.py:469(set_facecolor)
#         4    0.000    0.000    0.000    0.000 std.py:113(__exit__)
#         2    0.000    0.000    0.000    0.000 __init__.py:9(is_available)
#         8    0.000    0.000    0.000    0.000 transforms.py:1759(<lambda>)
#         4    0.000    0.000    0.000    0.000 hmac.py:94(update)
#         1    0.000    0.000    0.000    0.000 backend_bases.py:3576(new_figure_manager_given_figure)
#         2    0.000    0.000    0.000    0.000 PngImagePlugin.py:271(add)
#         4    0.000    0.000    0.000    0.000 cm.py:87(__len__)
#         1    0.000    0.000    0.000    0.000 _monitor.py:94(report)
#         1    0.000    0.000    0.000    0.000 pyplot.py:388(draw_if_interactive)
#         1    0.000    0.000    0.000    0.000 figure.py:2150(_set_artist_props)
#         2    0.000    0.000    0.000    0.000 backend_agg.py:277(buffer_rgba)
#         1    0.000    0.000    0.000    0.000 formatters.py:953(__call__)
#         3    0.000    0.000    0.000    0.000 utils.py:151(wrapper_setattr)
#        10    0.000    0.000    0.000    0.000 serialization.py:417(__enter__)
#        10    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.lock' objects}
#         2    0.000    0.000    0.000    0.000 jsonutil.py:38(_ensure_tzinfo)
#         4    0.000    0.000    0.000    0.000 contextlib.py:375(_create_exit_wrapper)
#         1    0.000    0.000    0.000    0.000 backend_bases.py:2850(create_with_canvas)
#         1    0.000    0.000    0.000    0.000 gridspec.py:123(set_height_ratios)
#         8    0.000    0.000    0.000    0.000 figure.py:2688(get_layout_engine)
#         1    0.000    0.000    0.000    0.000 session.py:272(msg_header)
#         1    0.000    0.000    0.000    0.000 {method 'all' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 formatters.py:944(_check_return)
#         5    0.000    0.000    0.000    0.000 pyplot.py:198(_get_backend_mod)
#         1    0.000    0.000    0.000    0.000 iostream.py:342(send_multipart)
#         1    0.000    0.000    0.000    0.000 std.py:1148(__del__)
#         4    0.000    0.000    0.000    0.000 gridspec.py:191(<listcomp>)
#         4    0.000    0.000    0.000    0.000 __init__.py:73(get_projection_class)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.repr}
#         1    0.000    0.000    0.000    0.000 {method 'digest' of '_hashlib.HASH' objects}
#         1    0.000    0.000    0.000    0.000 decorators.py:45(wrapper)
#         1    0.000    0.000    0.000    0.000 _weakrefset.py:106(remove)
#         2    0.000    0.000    0.000    0.000 std.py:1158(__hash__)
#         2    0.000    0.000    0.000    0.000 __init__.py:53(__get__)
#         3    0.000    0.000    0.000    0.000 std.py:226(__init__)
#         8    0.000    0.000    0.000    0.000 fromnumeric.py:2519(_cumsum_dispatcher)
#         2    0.000    0.000    0.000    0.000 {method 'strip' of 'str' objects}
#         4    0.000    0.000    0.000    0.000 {built-in method sys._getframe}
#         1    0.000    0.000    0.000    0.000 utils.py:265(_supports_unicode)
#        10    0.000    0.000    0.000    0.000 {method 'keys' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 hmac.py:130(hexdigest)
#         2    0.000    0.000    0.000    0.000 figure.py:427(get_edgecolor)
#         1    0.000    0.000    0.000    0.000 jsonutil.py:77(json_clean)
#         5    0.000    0.000    0.000    0.000 artist.py:1093(get_label)
#         8    0.000    0.000    0.000    0.000 _tight_bbox.py:31(<lambda>)
#         4    0.000    0.000    0.000    0.000 gridspec.py:614(num2)
#        10    0.000    0.000    0.000    0.000 {method 'release' of '_thread.lock' objects}
#         2    0.000    0.000    0.000    0.000 pretty.py:184(group)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(inv)
#         1    0.000    0.000    0.000    0.000 grad_mode.py:255(__init__)
#         1    0.000    0.000    0.000    0.000 session.py:854(<listcomp>)
#         2    0.000    0.000    0.000    0.000 Image.py:580(_ensure_mutable)
#         4    0.000    0.000    0.000    0.000 _base.py:3987(set_navigate_mode)
#         1    0.000    0.000    0.000    0.000 hmac.py:111(_current)
#         1    0.000    0.000    0.000    0.000 figure.py:2695(_repr_html_)
#         6    0.000    0.000    0.000    0.000 std.py:163(colour)
#         1    0.000    0.000    0.000    0.000 pretty.py:490(__init__)
#         1    0.000    0.000    0.000    0.000 linalg.py:112(_makearray)
#         2    0.000    0.000    0.000    0.000 _weakrefset.py:52(_commit_removals)
#         1    0.000    0.000    0.000    0.000 pretty.py:232(text)
#         2    0.000    0.000    0.000    0.000 PngImagePlugin.py:268(__init__)
#         4    0.000    0.000    0.000    0.000 gridspec.py:610(num2)
#         2    0.000    0.000    0.000    0.000 distributed_c10d.py:453(default_pg)
#         2    0.000    0.000    0.000    0.000 dataset.py:401(__len__)
#         4    0.000    0.000    0.000    0.000 _base.py:3971(set_navigate)
#         2    0.000    0.000    0.000    0.000 _weakrefset.py:16(__init__)
#         1    0.000    0.000    0.000    0.000 figure.py:82(__init__)
#         2    0.000    0.000    0.000    0.000 figure.py:2925(set_canvas)
#         5    0.000    0.000    0.000    0.000 metric.py:257(device)
#         1    0.000    0.000    0.000    0.000 std.py:763(get_lock)
#         2    0.000    0.000    0.000    0.000 __init__.py:119(__eq__)
#         4    0.000    0.000    0.000    0.000 spines.py:538(__init__)
#         1    0.000    0.000    0.000    0.000 grad_mode.py:262(__new__)
#         4    0.000    0.000    0.000    0.000 artist.py:608(set_url)
#         1    0.000    0.000    0.000    0.000 pretty.py:417(_in_deferred_types)
#         4    0.000    0.000    0.000    0.000 contextlib.py:700(__enter__)
#         1    0.000    0.000    0.000    0.000 {method 'squeeze' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 backend_inline.py:255(_is_transparent)
#         2    0.000    0.000    0.000    0.000 std.py:1154(_comparable)
#         1    0.000    0.000    0.000    0.000 iostream.py:270(send_multipart)
#         1    0.000    0.000    0.000    0.000 utils.py:124(__eq__)
#         2    0.000    0.000    0.000    0.000 PngImagePlugin.py:1072(__init__)
#         2    0.000    0.000    0.000    0.000 inspect.py:513(_is_wrapper)
#         1    0.000    0.000    0.000    0.000 utils.py:155(__init__)
#         4    0.000    0.000    0.000    0.000 __init__.py:116(__call__)
#         3    0.000    0.000    0.000    0.000 pretty.py:118(_safe_getattr)
#         1    0.000    0.000    0.000    0.000 {method 'splitlines' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 configurable.py:597(initialized)
#         2    0.000    0.000    0.000    0.000 pretty.py:512(remove)
#         4    0.000    0.000    0.000    0.000 multiarray.py:1029(unravel_index)
#         1    0.000    0.000    0.000    0.000 figure.py:3249(add_axobserver)
#         1    0.000    0.000    0.000    0.000 displaypub.py:43(_validate_data)
#         2    0.000    0.000    0.000    0.000 __init__.py:146(_DType_reduce)
#         4    0.000    0.000    0.000    0.000 gridspec.py:618(get_gridspec)
#         4    0.000    0.000    0.000    0.000 {method 'upper' of 'str' objects}
#         4    0.000    0.000    0.000    0.000 {method 'pop' of 'collections.deque' objects}
#         3    0.000    0.000    0.000    0.000 patches.py:292(get_facecolor)
#         2    0.000    0.000    0.000    0.000 widgets.py:38(__init__)
#         1    0.000    0.000    0.000    0.000 {method 'hexdigest' of '_hashlib.HASH' objects}
#         2    0.000    0.000    0.000    0.000 Image.py:302(preinit)
#         2    0.000    0.000    0.000    0.000 _util.py:10(is_path)
#         2    0.000    0.000    0.000    0.000 backend_bases.py:1646(<lambda>)
#         2    0.000    0.000    0.000    0.000 {method 'cleanup' of 'ImagingEncoder' objects}
#         2    0.000    0.000    0.000    0.000 {method 'islower' of 'bytes' objects}
#         1    0.000    0.000    0.000    0.000 linalg.py:186(_assert_stacked_square)
#         1    0.000    0.000    0.000    0.000 utils.py:281(_screen_shape_wrapper)
#         1    0.000    0.000    0.000    0.000 gridspec.py:101(set_width_ratios)
#         1    0.000    0.000    0.000    0.000 iostream.py:363(fileno)
#         4    0.000    0.000    0.000    0.000 multiarray.py:968(ravel_multi_index)
#         2    0.000    0.000    0.000    0.000 backend_bases.py:1744(_idle_draw_cntx)
#         2    0.000    0.000    0.000    0.000 figure.py:2603(_check_layout_engines_compat)
#         1    0.000    0.000    0.000    0.000 {method 'difference' of 'set' objects}
#         1    0.000    0.000    0.000    0.000 linalg.py:180(_assert_stacked_2d)
#         1    0.000    0.000    0.000    0.000 std.py:685(<setcomp>)
#         3    0.000    0.000    0.000    0.000 backend_bases.py:2057(draw)
#         1    0.000    0.000    0.000    0.000 linalg.py:107(get_linalg_error_extobj)
#         2    0.000    0.000    0.000    0.000 linalg.py:117(isComplexType)
#         2    0.000    0.000    0.000    0.000 {built-in method _weakref.proxy}
#         2    0.000    0.000    0.000    0.000 dataloader.py:607(__iter__)
#         1    0.000    0.000    0.000    0.000 __init__.py:1273(is_interactive)
#         1    0.000    0.000    0.000    0.000 backend_bases.py:1585(Done)
#         3    0.000    0.000    0.000    0.000 {method 'pop' of 'list' objects}
#         4    0.000    0.000    0.000    0.000 contextlib.py:479(__enter__)
#         1    0.000    0.000    0.000    0.000 {method 'discard' of 'set' objects}
#         2    0.000    0.000    0.000    0.000 patches.py:288(get_edgecolor)
#         4    0.000    0.000    0.000    0.000 contextlib.py:703(__exit__)
#         1    0.000    0.000    0.000    0.000 linalg.py:130(_realType)
#         1    0.000    0.000    0.000    0.000 transforms.py:293(p0)
#         1    0.000    0.000    0.000    0.000 backend_bases.py:1588(_draw)
#         2    0.000    0.000    0.000    0.000 utils.py:138(__getattr__)
#         1    0.000    0.000    0.000    0.000 {method 'move_to_end' of 'collections.OrderedDict' objects}
#         2    0.000    0.000    0.000    0.000 utils.py:221(__eq__)
#         1    0.000    0.000    0.000    0.000 utils.py:251(_is_utf)
#         1    0.000    0.000    0.000    0.000 {method 'getvalue' of '_io.StringIO' objects}
#         1    0.000    0.000    0.000    0.000 artist.py:1080(set_in_layout)
#         2    0.000    0.000    0.000    0.000 <string>:1(before_iter)
#         2    0.000    0.000    0.000    0.000 {built-in method sys.getrecursionlimit}
#         2    0.000    0.000    0.000    0.000 __init__.py:836(<dictcomp>)
#         2    0.000    0.000    0.000    0.000 ImageFile.py:88(_tilesort)
#         1    0.000    0.000    0.000    0.000 {method 'clear' of 'collections.OrderedDict' objects}
#         2    0.000    0.000    0.000    0.000 inspect.py:2543(default)
#         1    0.000    0.000    0.000    0.000 jsonutil.py:52(encode_images)
#         1    0.000    0.000    0.000    0.000 {method '__array_prepare__' of 'numpy.ndarray' objects}
#         2    0.000    0.000    0.000    0.000 <string>:1(after_iter)
#         1    0.000    0.000    0.000    0.000 tz.py:74(utcoffset)
#         1    0.000    0.000    0.000    0.000 formatters.py:830(_check_return)
#         1    0.000    0.000    0.000    0.000 linalg.py:465(_unary_dispatcher)
#         1    0.000    0.000    0.000    0.000 backend_bases.py:2925(destroy)
#         1    0.000    0.000    0.000    0.000 psnr.py:48(_psnr_param_check)
#         1    0.000    0.000    0.000    0.000 std.py:1302(<lambda>)
#         1    0.000    0.000    0.000    0.000 {method 'clear' of 'collections.deque' objects}
#         1    0.000    0.000    0.000    0.000 {method 'flush' of '_io.BytesIO' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 backend_bases.py:2941(set_window_title)

# %% [markdown]
# # Validation

# %%
def last_checkpoint(starter: str):
    return max([ f"checkpoint/{f}" for f in os.listdir('checkpoint') if f.startswith(starter) ], key=os.path.getctime)

G_model     =  ModifiedGenerator(128, in_sz=100+7*3, channels=channels, extra_layers=1).to(device)

# get the checkpoint with the latest date
checkpoint = last_checkpoint('G_')

# G_692 - basic, 128
G_model.load_state_dict(torch.load(f"{checkpoint}"))
print(f"loaded {checkpoint}")

losses = torch.load(last_checkpoint('l_'))
plot_GAN_losses(losses)

metrics = torch.load(last_checkpoint('m_'))
# plot_metric_per_epoch(metrics)

fakes = torch.load(last_checkpoint('f_'))
print(len(fakes), len(fakes[0]))
# print(metrics)
# Out:
# loaded checkpoint/G_1.pt
# 1 100

# %%
test = [ x for x in test_dataset ] 

xb = torch.Tensor(test[0][0]).to(device).unsqueeze(0)

yb = torch.Tensor(test[0][1]).repeat(1, 3).to(device)

yb_certainty = yb.repeat(channels, 140, 1)#1, 0, 2) # [ batch, x (classes), y, channels ]
# yb_certainty = nb.reshape(batch_size, channels, pixels, -1)
real = torch.cat( (xb, yb_certainty) , dim=2)

img = Image.fromarray((real.cpu().numpy() * 255).astype(np.uint8)[0])
plt.imshow(img)
# Out:
# /var/folders/8v/kyhpjx6d3y1b7dp0twz_83sw0000gn/T/ipykernel_20221/1232071673.py:11: RuntimeWarning: invalid value encountered in cast
#   img = Image.fromarray((real.cpu().numpy() * 255).astype(np.uint8)[0])

# %%
f, axarr = plt.subplots(2,3, figsize=(16,8))

test = [ x for x in test_dataset ] 

real = torch.Tensor(test[0][0]).to(device)

labels = torch.Tensor(test[0][1]).repeat(1, 3).to(device)

print(labels[0])
for i in range(2):
    for j in range(3):
        if i == 0 and j == 0:
            img = real.detach().cpu().numpy()
        else:
            rand = random_G_vector_input().unsqueeze(0)
            
            label = labels[0].to(device).unsqueeze(0)
            noise = torch.cat( (rand, label) , dim=1)
            fake = G_model.forward( noise ).cpu()
            img = fake.squeeze().squeeze().detach().numpy()

        img = Image.fromarray((img * 255).astype(np.uint8), mode='L')
        # display the image
        # plt.imshow(img)
        axarr[i,j].set_title("real" if i == 0 and j == 0 else "fake")
        axarr[i,j].imshow(img)#, interpolation='none', cmap='Blues'

        # TODO print comparison
# Out:
# tensor([ 0.9850,  0.2000, -1.0000, -1.0000,  1.0000, -1.0000,  0.3280,  0.9850,
#          0.2000, -1.0000, -1.0000,  1.0000, -1.0000,  0.3280,  0.9850,  0.2000,
#         -1.0000, -1.0000,  1.0000, -1.0000,  0.3280], device='mps:0')
# /var/folders/8v/kyhpjx6d3y1b7dp0twz_83sw0000gn/T/ipykernel_20221/572382551.py:22: RuntimeWarning: invalid value encountered in cast
#   img = Image.fromarray((img * 255).astype(np.uint8), mode='L')

# %%
from torcheval.metrics import PeakSignalNoiseRatio
from torcheval.metrics.image import FrechetInceptionDistance
from pytorch_msssim import ssim, ms_ssim

# fid = FrechetInceptionDistance(device=device)

# Generate some dummy data (replace with your real and generated images)
rand = random_G_vector_input().unsqueeze(0)
label = dataset[0][1].to(device).unsqueeze(0).repeat(1, 3)
noise = torch.cat( (rand, label) , dim=1)
fake = G_model.forward( noise )
print(fake.shape)

real = dataset[0][0].reshape(-1, pixels, pixels).unsqueeze(0).cuda()
print(real.shape)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[271], line 3
#       1 from torcheval.metrics import PeakSignalNoiseRatio
#       2 from torcheval.metrics.image import FrechetInceptionDistance
# ----> 3 from pytorch_msssim import ssim, ms_ssim
#       5 # fid = FrechetInceptionDistance(device=device)
#       6
#       7 # Generate some dummy data (replace with your real and generated images)
#       8 rand = random_G_vector_input().unsqueeze(0)
#
# ModuleNotFoundError: No module named 'pytorch_msssim'

# %%
feats = [ 'tg', 'Ng', 'Pci', 'H', 'Ox', 'Ow', 'Hbt' ]
test = [ x for x in test_dataset ]

epoch = checkpoint.split('.')[0].replace('G_','')
print(epoch)

for k in range(5):
    f, axarr = plt.subplots(2,3, figsize=(16,8))

    real = torch.Tensor(test[k][0]).to(device).reshape(1, -1, pixels, pixels)
    labels = torch.Tensor(test[k][1]).repeat(1, 3).to(device)

    for i in range(2):
        for j in range(3):
            if i == 0 and j == 0:
                img = real[0].detach().cpu().numpy()
            else:
                rand = random_G_vector_input().unsqueeze(0)

                label = labels[0].to(device).unsqueeze(0)
                noise = torch.cat( (rand, label) , dim=1)
                fake = G_model.forward( noise ).cpu()
                img = fake.squeeze(0).detach().numpy()

                img = img.reshape(-1).reshape(-1, pixels, pixels)
            img = Image.fromarray((img * 255).astype(np.uint8)[0], mode='L')
            # display the image
            # plt.imshow(img)
            axarr[i,j].set_title("real" if i == 0 and j == 0 else "fake")
            axarr[i,j].imshow(img)

    # the title is the names of the features and the value of them (label and remove the repeat)
    f.suptitle(' '.join([ f"{f}: {round(l.item(), 3)}" for f, l in zip(feats, labels[0][:len(feats)]) ]), fontsize=16)
    plt.savefig(f"{epoch}-{k}.png")

# # Adjust the layout and save
# plt.tight_layout()
# f.savefig("test.png", dpi=300, bbox_inches='tight')

# %%
import torch
from torcheval.metrics import FrechetInceptionDistance

fid = FrechetInceptionDistance()

real = torch.rand(64, 3, 299, 299)
fake = torch.rand(64, 3, 299, 299)

fid.update(real, is_real=True)
fid.update(fake, is_real=False)
score = fid.compute()
print(score)

# %%
test = [ x for x in test_dataset ]
print(len([x[0] for x in test]), type(test[0][0]))

real = torch.stack([x[0] for x in test], dim=0).to(device)
print(real.shape, len(real))
real = real.reshape(len(real), -1, pixels, pixels)

labels = torch.stack([x[1] for x in test], dim=0).to(device)
print(labels.shape, len(labels))
labels = labels.repeat(1, 3).to(device)

rand = noise_batch(len(real)).to(device)
noise = torch.cat( (rand, labels) , dim=1)
fake = G_model.forward( noise )

# %%
test = [ x for x in test_dataset ]

real = torch.stack([x[0] for x in test], dim=0).to(device)
real = real.reshape(len(real), -1, pixels, pixels)
real_fid = ((real + 1) / 2).repeat((1, 3, 1, 1))

psnrs = []
ssims = []
msssims = []
fids = []

for fake, metric in zip(fakes, metrics):
    fake = fake.to(device)
    
    psnr = PeakSignalNoiseRatio(device=device)
    psnr.update(fake, real)
    psnrs.append(psnr.compute())
    
    ssim_sc = ssim(real, fake, size_average=True)
    ssims.append(ssim_sc)
    msssim_sc = 0# ms_ssim(real, fake, size_average=True)
    # msssims.append(ms_ssim_sc)
    
    fid = FrechetInceptionDistance()
    fid.update(real_fid, is_real=True)
    fid.update(((fake + 1) / 2).repeat((1, 3, 1, 1)), is_real=False)
    fid_sc = fid.compute()
    fids.append(fid_sc)
    
    print(f"{metric['epoch']}:\t{psnr.compute()} Db;\tssim:{ssim_sc};\tms_ssim:{msssim_sc}\tfid_sc:{fid_sc}")

# %%
# create a plot of the metrics
plt.plot([metric['epoch'] for metric in metrics], [psnr.cpu() for psnr in psnrs])
plt.xlabel('epoch')
plt.ylabel('PSNR')
plt.title('PSNR per epoch')

# %%
# create a plot of the metrics
plt.plot([metric['epoch'] for metric in metrics], [ ssim.cpu() for ssim in ssims])
plt.xlabel('epoch')
plt.ylabel('SSIMS')
plt.title('SSIM per epoch')

# %%
# create a plot of the metrics
plt.plot([metric['epoch'] for metric in metrics], [ fid.cpu() for fid in fids])
plt.xlabel('epoch')
plt.ylabel('FIDS')
plt.title('FID per epoch')

# %%
test = [ x for x in test_dataset ]

real = torch.stack([x[0] for x in test], dim=0).to(device)
real = real.reshape(len(real), -1, pixels, pixels)
real_fid = ((real + 1) / 2).repeat((1, 3, 1, 1))

psnrs = []
ssims = []
fids = []

for i in range(100):
    metrics, fake = get_metrics(i)
    fake = fake.to(device)
    
    psnr = PeakSignalNoiseRatio(device=device)
    psnr.update(fake, real)
    psnrs.append(psnr.compute().cpu().numpy())
    
    ssim_sc = ssim(real, fake, size_average=True)
    ssims.append(ssim_sc.cpu().numpy())
    
    fid = FrechetInceptionDistance()
    fid.update(real_fid, is_real=True)
    fid.update(((fake + 1) / 2).repeat((1, 3, 1, 1)), is_real=False)
    fid_sc = fid.compute()
    fids.append(fid_sc.cpu().numpy())
    
    print(f"{metrics['epoch']}:\t{psnr.compute()} Db;\tssim:{ssim_sc};\tfid_sc:{fid_sc}")

# %%
# get the mean and std of the metrics
for name, metric in zip(['PSNR', 'SSIM', 'FID'], [psnrs, ssims, fids]):
    scores = [ m for m in metric ]
    print(f"{name}:\t{np.mean(scores)} ± {np.std(scores)}")

# %%
for name, metric in zip(['PSNR', 'SSIM', 'FID'], [psnrs, ssims, fids]):
    scores = [ m for m in metric ]
    print(f"{name}:\t{np.mean(scores)} ± {np.std(scores)}")
